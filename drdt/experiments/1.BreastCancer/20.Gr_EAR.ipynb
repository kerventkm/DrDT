# %%
import itertools
import pandas as pd
from importlib import resources
from tqdm import tqdm

from drdt.algorithms import A_C_G

# %%
with resources.path('datasets.DecisionRuleSystems', 'DRS_breast_cancer') as dataset_path:
    S = pd.read_csv(dataset_path)   
S
# Out:
#        age menopause tumor-size inv-nodes node-caps  deg-malig breast  \
# 0    30-39       NaN      30-34       NaN       NaN        NaN    NaN
# 1      NaN       NaN      20-24       0-2       NaN        NaN    NaN
# 2    40-49   premeno      20-24       0-2        no        2.0   left
# 3    60-69       NaN      15-19       NaN       NaN        NaN    NaN
# 4    40-49       NaN        0-4       NaN       NaN        NaN    NaN
# ..     ...       ...        ...       ...       ...        ...    ...
# 281  30-39   premeno      30-34       0-2        no        2.0   left
# 282  30-39       NaN      20-24       NaN       NaN        3.0    NaN
# 283  60-69       NaN      20-24       NaN       NaN        1.0  right
# 284    NaN       NaN      30-34     5-Mar        no        NaN    NaN
# 285    NaN       NaN      30-34     5-Mar        no        NaN    NaN
#
#     breast-quad irradiat                 class
# 0      left_low      NaN  no-recurrence-events
# 1      right_up      NaN  no-recurrence-events
# 2      left_low       no  no-recurrence-events
# 3           NaN      NaN  no-recurrence-events
# 4           NaN      NaN  no-recurrence-events
# ..          ...      ...                   ...
# 281     left_up       no     recurrence-events
# 282     left_up      NaN     recurrence-events
# 283         NaN      NaN     recurrence-events
# 284         NaN      NaN     recurrence-events
# 285         NaN      NaN     recurrence-events
#
# [286 rows x 10 columns]

# %%
res = 1

for col in S.columns[:-1]:
    res *= len(S[col].unique())
    
print("number of possible combinations =", res)
# Out:
# number of possible combinations = 1741824

# %%
# Possible values for each featue
age_values = ['30-39', '40-49', '60-69', '50-59', '70-79', '20-29', '*']
menopause_values = ['premeno', 'ge40', 'lt40', '*']
tumor_size_values = ['30-34', '20-24', '15-19', '0-4', '25-29', '50-54', '14-Oct', '40-44', '35-39', '9-May', '45-49', '*']
inv_nodes_values = ['0-2', '8-Jun', '11-Sep', '5-Mar', '15-17', '14-Dec', '24-26', '*'] 
node_caps_values = ['no', 'yes', '*']
deg_malig_values = [1, 2, 3, '*']
breast_values = ['left', 'right', '*']
breast_quad_values = ['left_low', 'right_up', 'left_up', 'central', 'right_low', '*']
irradiat_values = ['no', 'yes', '*']


# All possible combinations
combinations = list(itertools.product(age_values, 
                                      menopause_values, 
                                      tumor_size_values, 
                                      inv_nodes_values, 
                                      node_caps_values, 
                                      deg_malig_values,
                                      breast_values,
                                      breast_quad_values,
                                      irradiat_values))

# %%
depths = []

for comb in tqdm(combinations):
    #creating delta
    delta = pd.DataFrame(
    [[comb[0], comb[1], comb[2], comb[3], comb[4], comb[5], comb[6], comb[7], comb[8]]],
    columns=['age',
             'menopause',
             'tumor-size',
             'inv-nodes', 
             'node-caps', 
             'deg-malig',
             'breast',
             'breast-quad',
             'irradiat'])
    
    delta = delta.loc[0]
    
    alg = A_C_G(C="EAR")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
# Out:
#   0%|                                  | 4532/1741824 [00:54<5:46:35, 83.54it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#      17 delta = delta.loc[0]
#      19 alg = A_C_G(C="EAR")
# ---> 21 depth, _ = alg.solve(S, delta=delta)
#      23 depths.append(depth)
#
# File ~/Desktop/DrDt/drdt/algorithms.py:257, in A_C_G.solve(self, S, delta)
#     254             while True:
#     255                 # Step 1
#     256                 P = self.R_C(Q)
# --> 257                 if (P.empty or P.iloc[:, :-1].isna().all().all()):
#     258                     if P.empty:
#     259 #                             print("There is no such rule")
#     260                         return self.depth, self.rules
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:10899, in NDFrame._add_numeric_operations.<locals>.all(self, axis, bool_only, skipna, level, **kwargs)
#   10888 @doc(
#   10889     _bool_doc,
#   10890     desc=_all_desc,
#    (...)
#   10897 )
#   10898 def all(self, axis=0, bool_only=None, skipna=True, level=None, **kwargs):
# > 10899     return NDFrame.all(self, axis, bool_only, skipna, level, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:10471, in NDFrame.all(self, axis, bool_only, skipna, level, **kwargs)
#   10463 def all(
#   10464     self,
#   10465     axis: Axis = 0,
#    (...)
#   10469     **kwargs,
#   10470 ) -> Series | bool_t:
# > 10471     return self._logical_func(
#   10472         "all", nanops.nanall, axis, bool_only, skipna, level, **kwargs
#   10473     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:10442, in NDFrame._logical_func(self, name, func, axis, bool_only, skipna, level, **kwargs)
#   10439         obj = self._get_bool_data()
#   10440     return obj._reduce_axis1(name, func, skipna=skipna)
# > 10442 return self._reduce(
#   10443     func,
#   10444     name=name,
#   10445     axis=axis,
#   10446     skipna=skipna,
#   10447     numeric_only=bool_only,
#   10448     filter_type="bool",
#   10449 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:10014, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   10010 ignore_failures = numeric_only is None
#   10012 # After possibly _get_data and transposing, we are now in the
#   10013 #  simple case where we can use BlockManager.reduce
# > 10014 res, _ = df._mgr.reduce(blk_func, ignore_failures=ignore_failures)
#   10015 out = df._constructor(res).iloc[0]
#   10016 if out_dtype is not None:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py:1392, in BlockManager.reduce(self, func, ignore_failures)
#    1389     nbs = blk.reduce(func, ignore_failures)
#    1390     res_blocks.extend(nbs)
# -> 1392 index = Index([None])  # placeholder
#    1393 if ignore_failures:
#    1394     if res_blocks:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:534, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     528 subarr = com.asarray_tuplesafe(data, dtype=_dtype_obj)
#     529 if dtype is None:
#     530     # with e.g. a list [1, 2, 3] casting to numeric is _not_ deprecated
#     531     # error: Incompatible types in assignment (expression has type
#     532     # "Union[ExtensionArray, ndarray[Any, Any]]", variable has type
#     533     # "ndarray[Any, Any]")
# --> 534     subarr = _maybe_cast_data_without_dtype(  # type: ignore[assignment]
#     535         subarr, cast_numeric_deprecated=False
#     536     )
#     537     dtype = subarr.dtype
#     538 return Index(subarr, dtype=dtype, copy=copy, name=name, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:7124, in _maybe_cast_data_without_dtype(subarr, cast_numeric_deprecated)
#    7106 def _maybe_cast_data_without_dtype(
#    7107     subarr: np.ndarray, cast_numeric_deprecated: bool = True
#    7108 ) -> ArrayLike:
#    7109     """
#    7110     If we have an arraylike input but no passed dtype, try to infer
#    7111     a supported dtype.
#    (...)
#    7121     np.ndarray or ExtensionArray
#    7122     """
# -> 7124     result = lib.maybe_convert_objects(
#    7125         subarr,
#    7126         convert_datetime=True,
#    7127         convert_timedelta=True,
#    7128         convert_period=True,
#    7129         convert_interval=True,
#    7130         dtype_if_all_nat=np.dtype("datetime64[ns]"),
#    7131     )
#    7132     if result.dtype.kind in ["i", "u", "f"]:
#    7133         if not cast_numeric_deprecated:
#    7134             # i.e. we started with a list, not an ndarray[object]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2461, in pandas._libs.lib.maybe_convert_objects()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/numeric.py:289, in full(shape, fill_value, dtype, order, like)
#     285 def _full_dispatcher(shape, fill_value, dtype=None, order=None, *, like=None):
#     286     return(like,)
# --> 289 @set_array_function_like_doc
#     290 @set_module('numpy')
#     291 def full(shape, fill_value, dtype=None, order='C', *, like=None):
#     292     """
#     293     Return a new array of given shape and type, filled with `fill_value`.
#     294
#    (...)
#     335
#     336     """
#     337     if like is not None:
#
# KeyboardInterrupt:

# %%
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
