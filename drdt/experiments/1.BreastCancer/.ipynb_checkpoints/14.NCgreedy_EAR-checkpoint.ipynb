# %%
import itertools
import pandas as pd
from importlib import resources
from tqdm import tqdm

from drdt.algorithms import A_C_N

# %%
with resources.path('datasets.DecisionRuleSystems', 'DRS_breast_cancer') as dataset_path:
    S = pd.read_csv(dataset_path)   
S
# Out:
#        age menopause tumor-size inv-nodes node-caps  deg-malig breast  \
# 0    30-39       NaN      30-34       NaN       NaN        NaN    NaN
# 1      NaN       NaN      20-24       0-2       NaN        NaN    NaN
# 2    40-49   premeno      20-24       0-2        no        2.0   left
# 3    60-69       NaN      15-19       NaN       NaN        NaN    NaN
# 4    40-49       NaN        0-4       NaN       NaN        NaN    NaN
# ..     ...       ...        ...       ...       ...        ...    ...
# 281  30-39   premeno      30-34       0-2        no        2.0   left
# 282  30-39       NaN      20-24       NaN       NaN        3.0    NaN
# 283  60-69       NaN      20-24       NaN       NaN        1.0  right
# 284    NaN       NaN      30-34     5-Mar        no        NaN    NaN
# 285    NaN       NaN      30-34     5-Mar        no        NaN    NaN
#
#     breast-quad irradiat                 class
# 0      left_low      NaN  no-recurrence-events
# 1      right_up      NaN  no-recurrence-events
# 2      left_low       no  no-recurrence-events
# 3           NaN      NaN  no-recurrence-events
# 4           NaN      NaN  no-recurrence-events
# ..          ...      ...                   ...
# 281     left_up       no     recurrence-events
# 282     left_up      NaN     recurrence-events
# 283         NaN      NaN     recurrence-events
# 284         NaN      NaN     recurrence-events
# 285         NaN      NaN     recurrence-events
#
# [286 rows x 10 columns]

# %%
res = 1

for col in S.columns[:-1]:
    res *= len(S[col].unique())
    
print("number of possible combinations =", res)
# Out:
# number of possible combinations = 1741824

# %%
# Possible values for each featue
age_values = ['30-39', '40-49', '60-69', '50-59', '70-79', '20-29', '*']
menopause_values = ['premeno', 'ge40', 'lt40', '*']
tumor_size_values = ['30-34', '20-24', '15-19', '0-4', '25-29', '50-54', '14-Oct', '40-44', '35-39', '9-May', '45-49', '*']
inv_nodes_values = ['0-2', '8-Jun', '11-Sep', '5-Mar', '15-17', '14-Dec', '24-26', '*'] 
node_caps_values = ['no', 'yes', '*']
deg_malig_values = [1, 2, 3, '*']
breast_values = ['left', 'right', '*']
breast_quad_values = ['left_low', 'right_up', 'left_up', 'central', 'right_low', '*']
irradiat_values = ['no', 'yes', '*']


# All possible combinations
combinations = list(itertools.product(age_values, 
                                      menopause_values, 
                                      tumor_size_values, 
                                      inv_nodes_values, 
                                      node_caps_values, 
                                      deg_malig_values,
                                      breast_values,
                                      breast_quad_values,
                                      irradiat_values))

# %%
depths = []

for comb in tqdm(combinations):
    #creating delta
    delta = pd.DataFrame(
    [[comb[0], comb[1], comb[2], comb[3], comb[4], comb[5], comb[6], comb[7], comb[8]]],
    columns=['age',
             'menopause',
             'tumor-size',
             'inv-nodes', 
             'node-caps', 
             'deg-malig',
             'breast',
             'breast-quad',
             'irradiat'])
    
    delta = delta.loc[0]
    
    alg = A_C_N(C="EAR", N="greedy")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
# Out:
#   0%|                                 | 3868/1741824 [02:08<16:05:52, 29.99it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#      17 delta = delta.loc[0]
#      19 alg = A_C_N(C="EAR", N="greedy")
# ---> 21 depth, _ = alg.solve(S, delta=delta)
#      23 depths.append(depth)
#
# File ~/Desktop/DrDt/drdt/algorithms.py:71, in A_C_N.solve(self, S, delta)
#      68                 while True:
#      69                     # Step 1
#      70                     P = self.R_C(Q)
# ---> 71                     if (P.empty or P.iloc[:, :-1].isna().all().all()):
#      72                         if P.empty:
#      73 #                             print("There is no such rule")
#      74                             return self.depth, self.rules
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1462, in _iLocIndexer._getitem_tuple(self, tup)
#    1459 with suppress(IndexingError):
#    1460     return self._getitem_lowerdim(tup)
# -> 1462 return self._getitem_tuple_same_dim(tup)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:827, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#     824 if com.is_null_slice(key):
#     825     continue
# --> 827 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     828 # We should never have retval.ndim < self.ndim, as that should
#     829 #  be handled by the _getitem_lowerdim call above.
#     830 assert retval.ndim == self.ndim
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1497, in _iLocIndexer._getitem_axis(self, key, axis)
#    1491     raise IndexError(
#    1492         "DataFrame indexer is not allowed for .iloc\n"
#    1493         "Consider using .loc for automatic alignment."
#    1494     )
#    1496 if isinstance(key, slice):
# -> 1497     return self._get_slice_axis(key, axis=axis)
#    1499 if is_iterator(key):
#    1500     key = list(key)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1533, in _iLocIndexer._get_slice_axis(self, slice_obj, axis)
#    1531 labels = obj._get_axis(axis)
#    1532 labels._validate_positional_slice(slice_obj)
# -> 1533 return self.obj._slice(slice_obj, axis=axis)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:3916, in NDFrame._slice(self, slobj, axis)
#    3914 assert isinstance(slobj, slice), type(slobj)
#    3915 axis = self._get_block_manager_axis(axis)
# -> 3916 result = self._constructor(self._mgr.get_slice(slobj, axis=axis))
#    3917 result = result.__finalize__(self)
#    3919 # this could be a view
#    3920 # but only in a single-dtyped view sliceable case
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/internals.pyx:815, in pandas._libs.internals.BlockManager.get_slice()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py:844, in BaseBlockManager._slice_take_blocks_ax0(self, slice_or_indexer, fill_value, only_slice, use_na_proxy)
#     842                     blocks.append(nb)
#     843             else:
# --> 844                 nb = blk.take_nd(taker, axis=0, new_mgr_locs=mgr_locs)
#     845                 blocks.append(nb)
#     847 return blocks
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py:1132, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1129 values = self.values
#    1131 if fill_value is lib.no_default:
# -> 1132     fill_value = self.fill_value
#    1133     allow_fill = False
#    1134 else:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/properties.pyx:37, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py:238, in Block.fill_value(self)
#     233 def values_for_json(self) -> np.ndarray:
#     234     # Incompatible return value type (got "Union[ndarray[Any, Any],
#     235     # ExtensionArray]", expected "ndarray[Any, Any]")
#     236     return self.values  # type: ignore[return-value]
# --> 238 @final
#     239 @cache_readonly
#     240 def fill_value(self):
#     241     # Used in reindex_indexer
#     242     return na_value_for_dtype(self.dtype, compat=False)
#     244 @property
#     245 def mgr_locs(self) -> BlockPlacement:
#
# KeyboardInterrupt:

# %%
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
