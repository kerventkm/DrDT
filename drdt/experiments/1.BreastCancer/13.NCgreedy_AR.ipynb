# %%
import itertools
import pandas as pd
from importlib import resources
from tqdm import tqdm

from drdt.algorithms import A_C_N

# %%
with resources.path('datasets.DecisionRuleSystems', 'DRS_breast_cancer') as dataset_path:
    S = pd.read_csv(dataset_path)   
S
# Out:
#        age menopause tumor-size inv-nodes node-caps  deg-malig breast  \
# 0    30-39       NaN      30-34       NaN       NaN        NaN    NaN
# 1      NaN       NaN      20-24       0-2       NaN        NaN    NaN
# 2    40-49   premeno      20-24       0-2        no        2.0   left
# 3    60-69       NaN      15-19       NaN       NaN        NaN    NaN
# 4    40-49       NaN        0-4       NaN       NaN        NaN    NaN
# ..     ...       ...        ...       ...       ...        ...    ...
# 281  30-39   premeno      30-34       0-2        no        2.0   left
# 282  30-39       NaN      20-24       NaN       NaN        3.0    NaN
# 283  60-69       NaN      20-24       NaN       NaN        1.0  right
# 284    NaN       NaN      30-34     5-Mar        no        NaN    NaN
# 285    NaN       NaN      30-34     5-Mar        no        NaN    NaN
#
#     breast-quad irradiat                 class
# 0      left_low      NaN  no-recurrence-events
# 1      right_up      NaN  no-recurrence-events
# 2      left_low       no  no-recurrence-events
# 3           NaN      NaN  no-recurrence-events
# 4           NaN      NaN  no-recurrence-events
# ..          ...      ...                   ...
# 281     left_up       no     recurrence-events
# 282     left_up      NaN     recurrence-events
# 283         NaN      NaN     recurrence-events
# 284         NaN      NaN     recurrence-events
# 285         NaN      NaN     recurrence-events
#
# [286 rows x 10 columns]

# %%
res = 1

for col in S.columns[:-1]:
    res *= len(S[col].unique())-1
    
print("number of possible combinations =", res)
# Out:
# number of possible combinations = 166320

# %%
# Possible values for each featue
age_values = ['30-39', '40-49', '60-69', '50-59', '70-79', '20-29']
menopause_values = ['premeno', 'ge40', 'lt40']
tumor_size_values = ['30-34', '20-24', '15-19', '0-4', '25-29', '50-54', '14-Oct', '40-44', '35-39', '9-May', '45-49']
inv_nodes_values = ['0-2', '8-Jun', '11-Sep', '5-Mar', '15-17', '14-Dec', '24-26'] 
node_caps_values = ['no', 'yes']
deg_malig_values = [1, 2, 3]
breast_values = ['left', 'right']
breast_quad_values = ['left_low', 'right_up', 'left_up', 'central', 'right_low']
irradiat_values = ['no', 'yes']


# All possible combinations
combinations = list(itertools.product(age_values, 
                                      menopause_values, 
                                      tumor_size_values, 
                                      inv_nodes_values, 
                                      node_caps_values, 
                                      deg_malig_values,
                                      breast_values,
                                      breast_quad_values,
                                      irradiat_values))

# %%
depths = []

for comb in tqdm(combinations):
    #creating delta
    delta = pd.DataFrame(
    [[comb[0], comb[1], comb[2], comb[3], comb[4], comb[5], comb[6], comb[7], comb[8]]],
    columns=['age',
             'menopause',
             'tumor-size',
             'inv-nodes', 
             'node-caps', 
             'deg-malig',
             'breast',
             'breast-quad',
             'irradiat'])
    
    delta = delta.loc[0]
    
    alg = A_C_N(C="AR", N="greedy")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
# Out:
#   2%|▊                                  | 3996/166320 [02:05<1:25:08, 31.77it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#      17 delta = delta.loc[0]
#      19 alg = A_C_N(C="AR", N="greedy")
# ---> 21 depth, _ = alg.solve(S, delta=delta)
#      23 depths.append(depth)
#
# File ~/Desktop/DrDt/drdt/algorithms.py:82, in A_C_N.solve(self, S, delta)
#      79 # Step 2
#      80 else:
#      81     P_plus = SPlus(P)
# ---> 82     B = NGreedy(P_plus)
#      84     if len(B) == num_of_features:    # Checking, if they are same no need to run further
#      85         return num_of_features, "when we focus just depth"
#
# File ~/Desktop/DrDt/drdt/helper_functions.py:262, in NGreedy(S_plus)
#     260 if col in B:
#     261     continue  # Skip columns that have already been chosen
# --> 262 cover = S_max.index[S_max[col].notna()].intersection(uncovered_rows)
#     263 if len(cover) > max_cover:
#     264     max_cover = len(cover)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3347, in Index.intersection(self, other, sort)
#    3344     other = other.astype(dtype, copy=False)
#    3345     return this.intersection(other, sort=sort)
# -> 3347 result = self._intersection(other, sort=sort)
#    3348 return self._wrap_intersection_result(other, result)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3365, in Index._intersection(self, other, sort)
#    3362         res = algos.unique1d(result)
#    3363         return ensure_wrapped_if_datetimelike(res)
# -> 3365 res_values = self._intersection_via_get_indexer(other, sort=sort)
#    3366 res_values = _maybe_try_sort(res_values, sort)
#    3367 return res_values
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3387, in Index._intersection_via_get_indexer(self, other, sort)
#    3384 right_unique = other.unique()
#    3386 # even though we are unique, we need get_indexer_for for IntervalIndex
# -> 3387 indexer = left_unique.get_indexer_for(right_unique)
#    3389 mask = indexer != -1
#    3391 taker = indexer.take(mask.nonzero()[0])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5764, in Index.get_indexer_for(self, target)
#    5746 """
#    5747 Guaranteed return of an indexer even when non-unique.
#    5748
#    (...)
#    5761 array([0, 2])
#    5762 """
#    5763 if self._index_as_unique:
# -> 5764     return self.get_indexer(target)
#    5765 indexer, _ = self.get_indexer_non_unique(target)
#    5766 return indexer
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3768, in Index.get_indexer(self, target, method, limit, tolerance)
#    3763 if pself is not self or ptarget is not target:
#    3764     return pself.get_indexer(
#    3765         ptarget, method=method, limit=limit, tolerance=tolerance
#    3766     )
# -> 3768 if is_dtype_equal(self.dtype, target.dtype) and self.equals(target):
#    3769     # Only call equals if we have same dtype to avoid inference/casting
#    3770     return np.arange(len(target), dtype=np.intp)
#    3772 if not is_dtype_equal(self.dtype, target.dtype) and not is_interval_dtype(
#    3773     self.dtype
#    3774 ):
#    3775     # IntervalIndex gets special treatment for partial-indexing
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5263, in Index.equals(self, other)
#    5259 if is_extension_array_dtype(other.dtype):
#    5260     # All EA-backed Index subclasses override equals
#    5261     return other.equals(self)
# -> 5263 return array_equivalent(self._values, other._values)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/missing.py:483, in array_equivalent(left, right, strict_nan, dtype_equal)
#     478 if (
#     479     left.dtype.type is np.void or right.dtype.type is np.void
#     480 ) and left.dtype != right.dtype:
#     481     return False
# --> 483 return np.array_equal(left, right)
#
# File <__array_function__ internals>:5, in array_equal(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/numeric.py:2446, in array_equal(a1, a2, equal_nan)
#    2444     return False
#    2445 if not equal_nan:
# -> 2446     return bool(asarray(a1 == a2).all())
#    2447 # Handling NaN values if equal_nan is True
#    2448 a1nan, a2nan = isnan(a1), isnan(a2)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:63, in _all(a, axis, dtype, out, keepdims, where)
#      60 def _all(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
#      61     # Parsing keyword arguments is currently fairly slow, so avoid it for now
#      62     if where is True:
# ---> 63         return umr_all(a, axis, dtype, out, keepdims)
#      64     return umr_all(a, axis, dtype, out, keepdims, where=where)
#
# KeyboardInterrupt:

# %%
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
