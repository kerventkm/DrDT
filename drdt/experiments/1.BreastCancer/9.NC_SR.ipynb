# %%
import itertools
import pandas as pd
from importlib import resources
from tqdm import tqdm

from drdt.algorithms import A_C_N

# %%
with resources.path('datasets.DecisionRuleSystems', 'DRS_breast_cancer') as dataset_path:
    S = pd.read_csv(dataset_path)   
S
# Out:
#        age menopause tumor-size inv-nodes node-caps  deg-malig breast  \
# 0    20-29       NaN        NaN       NaN       NaN        NaN    NaN
# 1    30-39      lt40        NaN       NaN       NaN        NaN    NaN
# 2      NaN       NaN        0-4       NaN       NaN        NaN    NaN
# 3    30-39       NaN     14-Oct       NaN       NaN        NaN    NaN
# 4    30-39       NaN     14-Oct       NaN       NaN        NaN    NaN
# ..     ...       ...        ...       ...       ...        ...    ...
# 261  70-79       NaN     14-Oct       NaN       NaN        NaN    NaN
# 262  70-79       NaN        NaN    11-Sep       NaN        NaN    NaN
# 263  70-79       NaN      20-24       NaN       NaN        NaN    NaN
# 264  70-79       NaN      40-44       NaN       NaN        NaN    NaN
# 265  70-79       NaN      40-44       NaN       NaN        NaN    NaN
#
#     breast-quad irradiat                 class
# 0           NaN      NaN  no-recurrence-events
# 1           NaN      NaN  no-recurrence-events
# 2           NaN      NaN  no-recurrence-events
# 3           NaN      NaN  no-recurrence-events
# 4           NaN      NaN  no-recurrence-events
# ..          ...      ...                   ...
# 261         NaN      NaN  no-recurrence-events
# 262         NaN      NaN     recurrence-events
# 263         NaN      NaN  no-recurrence-events
# 264         NaN      NaN  no-recurrence-events
# 265         NaN      NaN  no-recurrence-events
#
# [266 rows x 10 columns]

# %%
res = 1

for col in S.columns[:-1]:
    res *= len(S[col].unique())-1
    
print("number of possible combinations =", res)
# Out:
# number of possible combinations = 166320

# %%
# Possible values for each featue
age_values = ['30-39', '40-49', '60-69', '50-59', '70-79', '20-29']
menopause_values = ['premeno', 'ge40', 'lt40']
tumor_size_values = ['30-34', '20-24', '15-19', '0-4', '25-29', '50-54', '14-Oct', '40-44', '35-39', '9-May', '45-49']
inv_nodes_values = ['0-2', '8-Jun', '11-Sep', '5-Mar', '15-17', '14-Dec', '24-26'] 
node_caps_values = ['no', 'yes']
deg_malig_values = [1, 2, 3]
breast_values = ['left', 'right']
breast_quad_values = ['left_low', 'right_up', 'left_up', 'central', 'right_low']
irradiat_values = ['no', 'yes']


# All possible combinations
combinations = list(itertools.product(age_values, 
                                      menopause_values, 
                                      tumor_size_values, 
                                      inv_nodes_values, 
                                      node_caps_values, 
                                      deg_malig_values,
                                      breast_values,
                                      breast_quad_values,
                                      irradiat_values))

# %%
depths = []

for comb in tqdm(combinations):
    #creating delta
    delta = pd.DataFrame(
    [[comb[0], comb[1], comb[2], comb[3], comb[4], comb[5], comb[6], comb[7], comb[8]]],
    columns=['age',
             'menopause',
             'tumor-size',
             'inv-nodes', 
             'node-caps', 
             'deg-malig',
             'breast',
             'breast-quad',
             'irradiat'])
    
    delta = delta.loc[0]
    
    alg = A_C_N(C="SR", N="cover")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
# Out:
#   0%|                                   | 19/166320 [01:23<202:29:39,  4.38s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#      17 delta = delta.loc[0]
#      19 alg = A_C_N(C="SR", N="cover")
# ---> 21 depth, _ = alg.solve(S, delta=delta)
#      23 depths.append(depth)
#
# File ~/Desktop/DrDt/drdt/algorithms.py:103, in A_C_N.solve(self, S, delta)
#     100                 Q = S.copy()
#     101                 while True:
#     102                     # Step 1
# --> 103                     P = self.R_C(Q)
#     104                     if (P.empty or P.iloc[:, :-1].isna().all().all()):
#     105                         if P.empty:
#     106 #                             print("There is no such rule")
#
# File ~/Desktop/DrDt/drdt/helper_functions.py:37, in R_SR(S)
#      35 if i in to_remove or j in to_remove:
#      36     continue
# ---> 37 r1, r2 = S.iloc[i][:-1], S.iloc[j][:-1] # Exclude the last column
#      38 # Check if r1 is a subset of r2
#      39 if all(pd.isna(r1[k]) or r1[k] == r2[k] for k in S.columns[:-1]):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1522, in _iLocIndexer._getitem_axis(self, key, axis)
#    1519 # validate the location
#    1520 self._validate_integer(key, axis)
# -> 1522 return self.obj._ixs(key, axis=axis)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3424, in DataFrame._ixs(self, i, axis)
#    3422 # irow
#    3423 if axis == 0:
# -> 3424     new_values = self._mgr.fast_xs(i)
#    3426     # if we are a copy, mark as such
#    3427     copy = isinstance(new_values, np.ndarray) and new_values.base is None
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py:998, in BlockManager.fast_xs(self, loc)
#     995 if len(self.blocks) == 1:
#     996     return self.blocks[0].iget((slice(None), loc))
# --> 998 dtype = interleaved_dtype([blk.dtype for blk in self.blocks])
#    1000 n = len(self)
#    1001 if isinstance(dtype, ExtensionDtype):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/base.py:226, in interleaved_dtype(dtypes)
#     223 if not len(dtypes):
#     224     return None
# --> 226 return find_common_type(dtypes)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1841, in find_common_type(types)
#    1838         if is_integer_dtype(t) or is_float_dtype(t) or is_complex_dtype(t):
#    1839             return np.dtype("object")
# -> 1841 return np.find_common_type(types, [])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/numerictypes.py:654, in find_common_type(array_types, scalar_types)
#     651 array_types = [dtype(x) for x in array_types]
#     652 scalar_types = [dtype(x) for x in scalar_types]
# --> 654 maxa = _can_coerce_all(array_types)
#     655 maxsc = _can_coerce_all(scalar_types)
#     657 if maxa is None:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/numerictypes.py:584, in _can_coerce_all(dtypelist, start)
#     582 while thisind < __len_test_types:
#     583     newdtype = dtype(__test_types[thisind])
# --> 584     numcoerce = len([x for x in dtypelist if newdtype >= x])
#     585     if numcoerce == N:
#     586         return newdtype
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/numerictypes.py:584, in <listcomp>(.0)
#     582 while thisind < __len_test_types:
#     583     newdtype = dtype(__test_types[thisind])
# --> 584     numcoerce = len([x for x in dtypelist if newdtype >= x])
#     585     if numcoerce == N:
#     586         return newdtype
#
# KeyboardInterrupt:

# %%
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
