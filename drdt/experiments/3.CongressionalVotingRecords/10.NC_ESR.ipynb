# %%
import itertools
import pandas as pd
from importlib import resources
from tqdm import tqdm

from drdt.algorithms import A_C_N

# %%
with resources.path('datasets.DecisionRuleSystems', 'DRS_congressional_voting_records') as dataset_path:
    S = pd.read_csv(dataset_path)   
S
# Out:
#     handicapped-infants water-project-cost-sharing  \
# 0                   NaN                        NaN
# 1                   NaN                        NaN
# 2                   NaN                        NaN
# 3                   NaN                        NaN
# 4                   NaN                        NaN
# ..                  ...                        ...
# 430                 NaN                        NaN
# 431                 NaN                        NaN
# 432                 NaN                        NaN
# 433                 NaN                          n
# 434                 NaN                        NaN
#
#     adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                 NaN                  NaN             NaN
# 1                                 NaN                  NaN             NaN
# 2                                 NaN                  NaN             NaN
# 3                                 NaN                  NaN             NaN
# 4                                 NaN                  NaN             NaN
# ..                                ...                  ...             ...
# 430                               NaN                    y             NaN
# 431                               NaN                    n             NaN
# 432                               NaN                  NaN             NaN
# 433                               NaN                  NaN             NaN
# 434                                 n                  NaN             NaN
#
#     religious-groups-in-schools anti-satellite-test-ban mx-missile  \
# 0                           NaN                     NaN        NaN
# 1                           NaN                     NaN        NaN
# 2                           NaN                     NaN        NaN
# 3                           NaN                     NaN        NaN
# 4                           NaN                     NaN        NaN
# ..                          ...                     ...        ...
# 430                         NaN                     NaN        NaN
# 431                         NaN                     NaN        NaN
# 432                         NaN                     NaN        NaN
# 433                         NaN                     NaN        NaN
# 434                         NaN                     NaN        NaN
#
#     immigration synfuels-corporation-cutback education-spending  \
# 0           NaN                          NaN                NaN
# 1           NaN                          NaN                NaN
# 2           NaN                          NaN                NaN
# 3           NaN                          NaN                NaN
# 4           NaN                          NaN                NaN
# ..          ...                          ...                ...
# 430         NaN                          NaN                NaN
# 431         NaN                          NaN                NaN
# 432         NaN                          NaN                NaN
# 433         NaN                          NaN                NaN
# 434         NaN                          NaN                NaN
#
#     superfund-right-to-sue crime duty-free-exports  \
# 0                      NaN   NaN               NaN
# 1                      NaN   NaN               NaN
# 2                      NaN   NaN               NaN
# 3                      NaN   NaN               NaN
# 4                      NaN   NaN               NaN
# ..                     ...   ...               ...
# 430                    NaN   NaN               NaN
# 431                    NaN   NaN               NaN
# 432                    NaN   NaN               NaN
# 433                    NaN   NaN               NaN
# 434                    NaN   NaN               NaN
#
#     export-administration-act-south-africa       class
# 0                                      NaN  republican
# 1                                      NaN  republican
# 2                                      NaN    democrat
# 3                                      NaN    democrat
# 4                                      NaN    democrat
# ..                                     ...         ...
# 430                                    NaN  republican
# 431                                    NaN    democrat
# 432                                    NaN  republican
# 433                                    NaN  republican
# 434                                    NaN  republican
#
# [435 rows x 16 columns]

# %%
res = 1

for col in S.columns[:-1]:
    res *= len(S[col].unique())
    
print("number of possible combinations =", res)
# Out:
# number of possible combinations = 1889568

# %%
# Possible values for each featue
handicapped_infants_values = ['n','y', '*']
water_project_cost_sharing_values = ['n','y', '*']
adoption_of_the_budget_resolution_values = ['n','y', '*']
physician_fee_freeze_values = ['n','y', '*'] 
el_salvador_aid_values = ['n','y', '*']
religious_groups_in_schools_values = ['n', '*']
anti_satellite_test_ban_values = ['n','y', '*']
mx_missile_values = ['y', '*']
immigration_values = ['y', '*']
synfuels_corporation_cutback_values = ['n','y', '*']
education_spending_values = ['n','y', '*']
superfund_right_to_sue_values = ['n','y', '*']
crime_values = ['y', '*']
duty_free_exports_values = ['y', '*']
export_administration_act_south_africa_values = ['n','y', '*']


# All possible combinations
combinations = list(itertools.product(handicapped_infants_values, 
                                      water_project_cost_sharing_values, 
                                      adoption_of_the_budget_resolution_values, 
                                      physician_fee_freeze_values, 
                                      el_salvador_aid_values, 
                                      religious_groups_in_schools_values,
                                      anti_satellite_test_ban_values,
                                      mx_missile_values,
                                      immigration_values,
                                      synfuels_corporation_cutback_values,
                                      education_spending_values,
                                      superfund_right_to_sue_values,
                                      crime_values,
                                      duty_free_exports_values,
                                      export_administration_act_south_africa_values))

# %%
depths = []

for comb in tqdm(combinations):
    #creating delta
    delta = pd.DataFrame(
    [[comb[0], comb[1], comb[2], comb[3], comb[4], comb[5], comb[6], comb[7], comb[8], comb[9], comb[10], comb[11], comb[12], comb[13], comb[14]]],
    columns=['handicapped-infants',
             'water-project-cost-sharing',
             'adoption-of-the-budget-resolution',
             'physician-fee-freeze', 
             'el-salvador-aid', 
             'religious-groups-in-schools',
             'anti-satellite-test-ban',
             'mx-missile',
             'immigration',
             'synfuels-corporation-cutback',
             'education-spending',
             'superfund-right-to-sue',
             'crime',
             'duty-free-exports',
             'export-administration-act-south-africa'])
    
    delta = delta.loc[0]
    
    alg = A_C_N(C="ESR", N="cover")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
# Out:
#   0%|                                 | 1368/1889568 [01:34<36:19:43, 14.44it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#      23 delta = delta.loc[0]
#      25 alg = A_C_N(C="ESR", N="cover")
# ---> 27 depth, _ = alg.solve(S, delta=delta)
#      29 depths.append(depth)
#
# File ~/Desktop/DrDt/drdt/algorithms.py:103, in A_C_N.solve(self, S, delta)
#     100                 Q = S.copy()
#     101                 while True:
#     102                     # Step 1
# --> 103                     P = self.R_C(Q)
#     104                     if (P.empty or P.iloc[:, :-1].isna().all().all()):
#     105                         if P.empty:
#     106 #                             print("There is no such rule")
#
# File ~/Desktop/DrDt/drdt/helper_functions.py:39, in R_SR(S)
#      37 r1, r2 = S.iloc[i][:-1], S.iloc[j][:-1] # Exclude the last column
#      38 # Check if r1 is a subset of r2
# ---> 39 if all(pd.isna(r1[k]) or r1[k] == r2[k] for k in S.columns[:-1]):
#      40     to_remove.add(j)
#      41 # Check if r2 is a subset of r1
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/base.py:761, in IndexOpsMixin.__iter__(self)
#     759     return iter(self._values)
#     760 else:
# --> 761     return map(self._values.item, range(self._values.size))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:4820, in Index._values(self)
#    4817         array = PandasArray(array)
#    4818     return array
# -> 4820 @property
#    4821 def _values(self) -> ExtensionArray | np.ndarray:
#    4822     """
#    4823     The best array representation.
#    4824
#    (...)
#    4842     values : Values
#    4843     """
#    4844     return self._data
#
# KeyboardInterrupt:

# %%
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
