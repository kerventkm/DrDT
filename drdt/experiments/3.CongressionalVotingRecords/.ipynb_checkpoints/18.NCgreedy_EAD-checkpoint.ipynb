# %%
import itertools
import pandas as pd
from importlib import resources
from tqdm import tqdm

from drdt.algorithms import A_C_N

# %%
with resources.path('datasets.DecisionRuleSystems', 'DRS_congressional_voting_records') as dataset_path:
    S = pd.read_csv(dataset_path)   
S
# Out:
#     handicapped-infants water-project-cost-sharing  \
# 0                     n                        NaN
# 1                   NaN                        NaN
# 2                   NaN                        NaN
# 3                   NaN                        NaN
# 4                     n                          n
# ..                  ...                        ...
# 274                   y                        NaN
# 275                   y                        NaN
# 276                 NaN                        NaN
# 277                 NaN                        NaN
# 278                   y                        NaN
#
#     adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                 NaN                    n             NaN
# 1                                 NaN                    n             NaN
# 2                                 NaN                    n             NaN
# 3                                 NaN                    n             NaN
# 4                                   n                  NaN             NaN
# ..                                ...                  ...             ...
# 274                               NaN                  NaN             NaN
# 275                               NaN                  NaN             NaN
# 276                               NaN                  NaN             NaN
# 277                               NaN                  NaN             NaN
# 278                               NaN                  NaN             NaN
#
#     religious-groups-in-schools anti-satellite-test-ban  \
# 0                             n                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
# ..                          ...                     ...
# 274                         NaN                     NaN
# 275                         NaN                     NaN
# 276                         NaN                     NaN
# 277                         NaN                     NaN
# 278                         NaN                     NaN
#
#     aid-to-nicaraguan-contras mx-missile immigration  \
# 0                         NaN        NaN         NaN
# 1                         NaN        NaN         NaN
# 2                         NaN        NaN         NaN
# 3                         NaN        NaN         NaN
# 4                         NaN        NaN         NaN
# ..                        ...        ...         ...
# 274                         y        NaN         NaN
# 275                       NaN        NaN         NaN
# 276                         n        NaN         NaN
# 277                         n        NaN         NaN
# 278                       NaN        NaN         NaN
#
#     synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 0                            NaN                NaN                    NaN
# 1                              y                NaN                    NaN
# 2                              y                NaN                    NaN
# 3                              y                NaN                    NaN
# 4                            NaN                  n                    NaN
# ..                           ...                ...                    ...
# 274                          NaN                NaN                    NaN
# 275                            n                NaN                    NaN
# 276                          NaN                NaN                    NaN
# 277                          NaN                NaN                    NaN
# 278                          NaN                NaN                    NaN
#
#     crime duty-free-exports export-administration-act-south-africa       class
# 0     NaN               NaN                                    NaN    democrat
# 1     NaN               NaN                                    NaN    democrat
# 2     NaN               NaN                                    NaN    democrat
# 3     NaN               NaN                                    NaN    democrat
# 4     NaN               NaN                                    NaN  republican
# ..    ...               ...                                    ...         ...
# 274   NaN               NaN                                    NaN  republican
# 275   NaN               NaN                                    NaN  republican
# 276   NaN               NaN                                    NaN    democrat
# 277   NaN               NaN                                    NaN    democrat
# 278   NaN               NaN                                    NaN  republican
#
# [279 rows x 17 columns]

# %%
res = 1

for col in S.columns[:-1]:
    res *= len(S[col].unique())
    
print("number of possible combinations =", res)
# Out:
# number of possible combinations = 5668704

# %%
# Possible values for each featue
handicapped_infants_values = ['n','y', '*']
water_project_cost_sharing_values = ['n','y', '*']
adoption_of_the_budget_resolution_values = ['n','y', '*']
physician_fee_freeze_values = ['n','y', '*'] 
el_salvador_aid_values = ['n', '*']
religious_groups_in_schools_values = ['n', '*']
anti_satellite_test_ban_values = ['n','y', '*']
aid_to_nicaraguan_contras_values = ['n','y', '*']
mx_missile_values = ['n','y', '*']
immigration_values = ['n','y', '*']
synfuels_corporation_cutback_values = ['n','y', '*']
education_spending_values = ['n','y', '*']
superfund_right_to_sue_values = ['n', '*']
crime_values = ['n', '*']
duty_free_exports_values = ['n', 'y', '*']
export_administration_act_south_africa_values = ['n', '*']


# All possible combinations
combinations = list(itertools.product(handicapped_infants_values, 
                                      water_project_cost_sharing_values, 
                                      adoption_of_the_budget_resolution_values, 
                                      physician_fee_freeze_values, 
                                      el_salvador_aid_values, 
                                      religious_groups_in_schools_values,
                                      anti_satellite_test_ban_values,
                                      aid_to_nicaraguan_contras_values,
                                      mx_missile_values,
                                      immigration_values,
                                      synfuels_corporation_cutback_values,
                                      education_spending_values,
                                      superfund_right_to_sue_values,
                                      crime_values,
                                      duty_free_exports_values,
                                      export_administration_act_south_africa_values))

# %%
depths = []

for comb in tqdm(combinations):
    #creating delta
    delta = pd.DataFrame(
    [[comb[0], comb[1], comb[2], comb[3], comb[4], comb[5], comb[6], comb[7], comb[8], comb[9], comb[10], comb[11], comb[12], comb[13], comb[14], comb[15]]],
    columns=['handicapped-infants',
             'water-project-cost-sharing',
             'adoption-of-the-budget-resolution',
             'physician-fee-freeze', 
             'el-salvador-aid', 
             'religious-groups-in-schools',
             'anti-satellite-test-ban',
             'aid-to-nicaraguan-contras',
             'mx-missile',
             'immigration',
             'synfuels-corporation-cutback',
             'education-spending',
             'superfund-right-to-sue',
             'crime',
             'duty-free-exports',
             'export-administration-act-south-africa'])
    
    delta = delta.loc[0]
    
    alg = A_C_N(C="EAD", N="greedy")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
# Out:
#   0%|                                  | 72/5668704 [00:31<678:07:46,  2.32it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#      24 delta = delta.loc[0]
#      26 alg = A_C_N(C="EAD", N="greedy")
# ---> 28 depth, _ = alg.solve(S, delta=delta)
#      30 depths.append(depth)
#
# File ~/Desktop/DrDt/drdt/algorithms.py:205, in A_C_N.solve(self, S, delta)
#     202 # Step 2
#     203 else:
#     204     P_plus = SPlus(P)
# --> 205     B = NGreedy(P_plus)
#     207     if len(B) == num_of_features:    # Checking, if they are same no need to run further
#     208         return num_of_features, "when we focus just depth"
#
# File ~/Desktop/DrDt/drdt/helper_functions.py:249, in NGreedy(S_plus)
#     244 def NGreedy(S_plus):
#     245     """
#     246     input: S_plus - subset of S as defined in the paper. (pandas DataFrame)
#     247     output: Node cover of S_plus, set of indecies of columns that covers all rows
#     248     """
# --> 249     S_max = SMax(S_plus)
#     251     B = set()
#     252     uncovered_rows = set(S_max.index)
#
# File ~/Desktop/DrDt/drdt/helper_functions.py:114, in SMax(S_plus)
#     107 """
#     108 input: S_plus - system of decision rules with length d (pandas DataFrame)
#     109 output: S_max - subset of S as defined in the paper. (pandas DataFrame)
#     110 """
#     112 columns_to_check = S_plus.columns[:-1]
# --> 114 S_max = S_plus.drop_duplicates(subset=columns_to_check, keep='first')
#     116 return S_max
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:6116, in DataFrame.drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6114 inplace = validate_bool_kwarg(inplace, "inplace")
#    6115 ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
# -> 6116 duplicated = self.duplicated(subset, keep=keep)
#    6118 result = self[-duplicated]
#    6119 if ignore_index:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:6253, in DataFrame.duplicated(self, subset, keep)
#    6250     raise KeyError(diff)
#    6252 vals = (col.values for name, col in self.items() if name in subset)
# -> 6253 labels, shape = map(list, zip(*map(f, vals)))
#    6255 ids = get_group_index(
#    6256     labels,
#    6257     # error: Argument 1 to "tuple" has incompatible type "List[_T]";
#    (...)
#    6261     xnull=False,
#    6262 )
#    6263 result = self._constructor_sliced(duplicated(ids, keep), index=self.index)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:6226, in DataFrame.duplicated.<locals>.f(vals)
#    6225 def f(vals) -> tuple[np.ndarray, int]:
# -> 6226     labels, shape = algorithms.factorize(vals, size_hint=len(self))
#    6227     return labels.astype("i8", copy=False), len(shape)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/algorithms.py:725, in factorize(values, sort, na_sentinel, size_hint)
#     723 original = values
#     724 if not isinstance(values, ABCMultiIndex):
# --> 725     values = extract_array(values, extract_numpy=True)
#     727 # GH35667, if na_sentinel=None, we will not dropna NaNs from the uniques
#     728 # of values, assign na_sentinel=-1 to replace code value for NaN.
#     729 dropna = True
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/construction.py:432, in extract_array(obj, extract_numpy, extract_range)
#     428         return obj
#     430     obj = obj._values
# --> 432 elif extract_numpy and isinstance(obj, ABCPandasArray):
#     433     obj = obj.to_numpy()
#     435 return obj
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/generic.py:45, in create_pandas_abc_type.<locals>._check(cls, inst)
#      43 @classmethod  # type: ignore[misc]
#      44 def _check(cls, inst) -> bool:
# ---> 45     return getattr(inst, attr, "_typ") in comp
#
# KeyboardInterrupt:

# %%
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
