# %%
import itertools
import pandas as pd
from importlib import resources
from tqdm import tqdm

from drdt.algorithms import A_C_N

# %%
with resources.path('datasets.DecisionRuleSystems', 'DRS_congressional_voting_records') as dataset_path:
    S = pd.read_csv(dataset_path)   
S
# Out:
#     handicapped-infants water-project-cost-sharing  \
# 0                     n                        NaN
# 1                   NaN                        NaN
# 2                   NaN                        NaN
# 3                   NaN                        NaN
# 4                     n                          n
# ..                  ...                        ...
# 274                   y                        NaN
# 275                   y                        NaN
# 276                 NaN                        NaN
# 277                 NaN                        NaN
# 278                   y                        NaN
#
#     adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                 NaN                    n             NaN
# 1                                 NaN                    n             NaN
# 2                                 NaN                    n             NaN
# 3                                 NaN                    n             NaN
# 4                                   n                  NaN             NaN
# ..                                ...                  ...             ...
# 274                               NaN                  NaN             NaN
# 275                               NaN                  NaN             NaN
# 276                               NaN                  NaN             NaN
# 277                               NaN                  NaN             NaN
# 278                               NaN                  NaN             NaN
#
#     religious-groups-in-schools anti-satellite-test-ban  \
# 0                             n                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
# ..                          ...                     ...
# 274                         NaN                     NaN
# 275                         NaN                     NaN
# 276                         NaN                     NaN
# 277                         NaN                     NaN
# 278                         NaN                     NaN
#
#     aid-to-nicaraguan-contras mx-missile immigration  \
# 0                         NaN        NaN         NaN
# 1                         NaN        NaN         NaN
# 2                         NaN        NaN         NaN
# 3                         NaN        NaN         NaN
# 4                         NaN        NaN         NaN
# ..                        ...        ...         ...
# 274                         y        NaN         NaN
# 275                       NaN        NaN         NaN
# 276                         n        NaN         NaN
# 277                         n        NaN         NaN
# 278                       NaN        NaN         NaN
#
#     synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 0                            NaN                NaN                    NaN
# 1                              y                NaN                    NaN
# 2                              y                NaN                    NaN
# 3                              y                NaN                    NaN
# 4                            NaN                  n                    NaN
# ..                           ...                ...                    ...
# 274                          NaN                NaN                    NaN
# 275                            n                NaN                    NaN
# 276                          NaN                NaN                    NaN
# 277                          NaN                NaN                    NaN
# 278                          NaN                NaN                    NaN
#
#     crime duty-free-exports export-administration-act-south-africa       class
# 0     NaN               NaN                                    NaN    democrat
# 1     NaN               NaN                                    NaN    democrat
# 2     NaN               NaN                                    NaN    democrat
# 3     NaN               NaN                                    NaN    democrat
# 4     NaN               NaN                                    NaN  republican
# ..    ...               ...                                    ...         ...
# 274   NaN               NaN                                    NaN  republican
# 275   NaN               NaN                                    NaN  republican
# 276   NaN               NaN                                    NaN    democrat
# 277   NaN               NaN                                    NaN    democrat
# 278   NaN               NaN                                    NaN  republican
#
# [279 rows x 17 columns]

# %%
res = 1

for col in S.columns[:-1]:
    res *= len(S[col].unique())
    
print("number of possible combinations =", res)
# Out:
# number of possible combinations = 5668704

# %%
# Possible values for each featue
handicapped_infants_values = ['n','y', '*']
water_project_cost_sharing_values = ['n','y', '*']
adoption_of_the_budget_resolution_values = ['n','y', '*']
physician_fee_freeze_values = ['n','y', '*'] 
el_salvador_aid_values = ['n', '*']
religious_groups_in_schools_values = ['n', '*']
anti_satellite_test_ban_values = ['n','y', '*']
aid_to_nicaraguan_contras_values = ['n','y', '*']
mx_missile_values = ['n','y', '*']
immigration_values = ['n','y', '*']
synfuels_corporation_cutback_values = ['n','y', '*']
education_spending_values = ['n','y', '*']
superfund_right_to_sue_values = ['n', '*']
crime_values = ['n', '*']
duty_free_exports_values = ['n', 'y', '*']
export_administration_act_south_africa_values = ['n', '*']


# All possible combinations
combinations = list(itertools.product(handicapped_infants_values, 
                                      water_project_cost_sharing_values, 
                                      adoption_of_the_budget_resolution_values, 
                                      physician_fee_freeze_values, 
                                      el_salvador_aid_values, 
                                      religious_groups_in_schools_values,
                                      anti_satellite_test_ban_values,
                                      aid_to_nicaraguan_contras_values,
                                      mx_missile_values,
                                      immigration_values,
                                      synfuels_corporation_cutback_values,
                                      education_spending_values,
                                      superfund_right_to_sue_values,
                                      crime_values,
                                      duty_free_exports_values,
                                      export_administration_act_south_africa_values))

# %%
depths = []

for comb in tqdm(combinations):
    #creating delta
    delta = pd.DataFrame(
    [[comb[0], comb[1], comb[2], comb[3], comb[4], comb[5], comb[6], comb[7], comb[8], comb[9], comb[10], comb[11], comb[12], comb[13], comb[14], comb[15]]],
    columns=['handicapped-infants',
             'water-project-cost-sharing',
             'adoption-of-the-budget-resolution',
             'physician-fee-freeze', 
             'el-salvador-aid', 
             'religious-groups-in-schools',
             'anti-satellite-test-ban',
             'aid-to-nicaraguan-contras',
             'mx-missile',
             'immigration',
             'synfuels-corporation-cutback',
             'education-spending',
             'superfund-right-to-sue',
             'crime',
             'duty-free-exports',
             'export-administration-act-south-africa'])
    
    delta = delta.loc[0]
    
    alg = A_C_N(C="EAR", N="greedy")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
# Out:
#   0%|                                 | 3265/5668704 [03:16<94:43:42, 16.61it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#      24 delta = delta.loc[0]
#      26 alg = A_C_N(C="EAR", N="greedy")
# ---> 28 depth, _ = alg.solve(S, delta=delta)
#      30 depths.append(depth)
#
# File ~/Desktop/DrDt/drdt/algorithms.py:71, in A_C_N.solve(self, S, delta)
#      68                 while True:
#      69                     # Step 1
#      70                     P = self.R_C(Q)
# ---> 71                     if (P.empty or P.iloc[:, :-1].isna().all().all()):
#      72                         if P.empty:
#      73 #                             print("There is no such rule")
#      74                             return self.depth, self.rules
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:10899, in NDFrame._add_numeric_operations.<locals>.all(self, axis, bool_only, skipna, level, **kwargs)
#   10888 @doc(
#   10889     _bool_doc,
#   10890     desc=_all_desc,
#    (...)
#   10897 )
#   10898 def all(self, axis=0, bool_only=None, skipna=True, level=None, **kwargs):
# > 10899     return NDFrame.all(self, axis, bool_only, skipna, level, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:10471, in NDFrame.all(self, axis, bool_only, skipna, level, **kwargs)
#   10463 def all(
#   10464     self,
#   10465     axis: Axis = 0,
#    (...)
#   10469     **kwargs,
#   10470 ) -> Series | bool_t:
# > 10471     return self._logical_func(
#   10472         "all", nanops.nanall, axis, bool_only, skipna, level, **kwargs
#   10473     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:10442, in NDFrame._logical_func(self, name, func, axis, bool_only, skipna, level, **kwargs)
#   10439         obj = self._get_bool_data()
#   10440     return obj._reduce_axis1(name, func, skipna=skipna)
# > 10442 return self._reduce(
#   10443     func,
#   10444     name=name,
#   10445     axis=axis,
#   10446     skipna=skipna,
#   10447     numeric_only=bool_only,
#   10448     filter_type="bool",
#   10449 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:10023, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   10018 if axis == 0 and len(self) == 0 and name in ["sum", "prod"]:
#   10019     # Even if we are object dtype, follow numpy and return
#   10020     #  float64, see test_apply_funcs_over_empty
#   10021     out = out.astype(np.float64)
# > 10023 if numeric_only is None and out.shape[0] != df.shape[1]:
#   10024     # columns have been dropped GH#41480
#   10025     arg_name = "numeric_only"
#   10026     if name in ["all", "any"]:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:841, in DataFrame.shape(self)
#     821 @property
#     822 def shape(self) -> tuple[int, int]:
#     823     """
#     824     Return a tuple representing the dimensionality of the DataFrame.
#     825
#    (...)
#     839     (2, 3)
#     840     """
# --> 841     return len(self.index), len(self.columns)
#
# KeyboardInterrupt:

# %%
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
