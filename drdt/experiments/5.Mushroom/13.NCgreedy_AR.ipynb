# %%
import itertools
import pandas as pd
from importlib import resources
from tqdm import tqdm

from drdt.algorithms import A_C_N

# %%
with resources.path('datasets.DecisionRuleSystems', 'DRS_mushroom') as dataset_path:
    S = pd.read_csv(dataset_path)   
S
# Out:
#      cap-shape cap-surface cap-color bruises odor gill-spacing gill-size  \
# 0          NaN         NaN       NaN     NaN    p          NaN       NaN
# 1          NaN         NaN       NaN     NaN    a          NaN       NaN
# 2          NaN         NaN       NaN     NaN    l          NaN       NaN
# 3          NaN         NaN       NaN     NaN    p          NaN       NaN
# 4          NaN         NaN       NaN     NaN  NaN          NaN       NaN
# ...        ...         ...       ...     ...  ...          ...       ...
# 8119       NaN         NaN       NaN     NaN    n          NaN       NaN
# 8120       NaN         NaN       NaN     NaN    n          NaN       NaN
# 8121         f         NaN       NaN     NaN  NaN          NaN       NaN
# 8122         k         NaN       NaN     NaN  NaN          NaN       NaN
# 8123       NaN         NaN       NaN       f  NaN          NaN       NaN
#
#      gill-color stalk-shape stalk-root stalk-surface-above-ring  \
# 0           NaN         NaN        NaN                      NaN
# 1           NaN         NaN        NaN                      NaN
# 2           NaN         NaN        NaN                      NaN
# 3           NaN         NaN        NaN                      NaN
# 4           NaN         NaN        NaN                      NaN
# ...         ...         ...        ...                      ...
# 8119        NaN         NaN        NaN                      NaN
# 8120        NaN         NaN        NaN                      NaN
# 8121        NaN         NaN        NaN                      NaN
# 8122        NaN         NaN        NaN                      NaN
# 8123        NaN         NaN        NaN                      NaN
#
#      stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 0                         NaN                    NaN                    NaN
# 1                         NaN                    NaN                    NaN
# 2                         NaN                    NaN                    NaN
# 3                         NaN                    NaN                    NaN
# 4                         NaN                    NaN                    NaN
# ...                       ...                    ...                    ...
# 8119                      NaN                    NaN                    NaN
# 8120                      NaN                    NaN                    NaN
# 8121                      NaN                    NaN                    NaN
# 8122                      NaN                    NaN                    NaN
# 8123                      NaN                    NaN                    NaN
#
#      ring-number ring-type spore-print-color population habitat class
# 0            NaN       NaN               NaN        NaN     NaN     p
# 1            NaN       NaN               NaN        NaN     NaN     e
# 2            NaN       NaN               NaN        NaN     NaN     e
# 3            NaN       NaN               NaN        NaN     NaN     p
# 4            NaN       NaN               NaN          a     NaN     e
# ...          ...       ...               ...        ...     ...   ...
# 8119         NaN       NaN               NaN        NaN     NaN     e
# 8120         NaN       NaN               NaN        NaN     NaN     e
# 8121         NaN       NaN               NaN        NaN     NaN     e
# 8122         NaN       NaN               NaN        NaN     NaN     p
# 8123         NaN       NaN               NaN        NaN     NaN     e
#
# [8124 rows x 20 columns]

# %%
res = 1

for col in S.columns[:-1]:
    res *= len(S[col].unique())-1
    
print("number of possible combinations =", res)
# Out:
# number of possible combinations = 1632960

# %%
# Possible values for each featue
cap_shape_values = ['s', 'f', 'b', 'x', 'c', 'k']
cap_surface_values = ['f', 'y', 'g']
cap_color_values = ['g', 'n', 'e', 'w', 'y', 'u', 'c', 'r', 'b', 'p']
bruises_values = ['f', 't'] 
odor_values = ['p', 'a', 'l', 'n', 'f', 'c', 'y', 's', 'm']
gill_spacing_values = ['w']
gill_size_values = ['b', 'n']
gill_color_values = ['k', 'n', 'p', 'u', 'e', 'r', 'o']
stalk_shape_values = ['t']
stalk_root_values = ['e']
stalk_surface_above_ring_values = ['f']
stalk_surface_below_ring_values = ['y']
stalk_color_above_ring_values = ['g', 'e', 'o', 'n']
stalk_color_below_ring_values = ['g', 'e', 'y']
ring_number_values = ["t"]
ring_type_values = ['f']
spore_print_color_values = ['n', 'k', 'r']
population_values = ['a']
habitat_values = ['w']


# All possible combinations
combinations = list(itertools.product(cap_shape_values, 
                                      cap_surface_values, 
                                      cap_color_values, 
                                      bruises_values, 
                                      odor_values, 
                                      gill_spacing_values,
                                      gill_size_values,
                                      gill_color_values,
                                      stalk_shape_values,
                                      stalk_root_values,
                                      stalk_surface_above_ring_values,
                                      stalk_surface_below_ring_values,
                                      stalk_color_above_ring_values,
                                      stalk_color_below_ring_values,
                                      ring_number_values,
                                      ring_type_values,
                                      spore_print_color_values,
                                      population_values,
                                      habitat_values))

# %%
depths = []

for comb in tqdm(combinations):
    #creating delta
    delta = pd.DataFrame(
    [[comb[0], comb[1], comb[2], comb[3], comb[4], comb[5], comb[6], comb[7], comb[8], comb[9], comb[10], comb[11], comb[12], comb[13], comb[14], comb[15], comb[16], comb[17], comb[18]]],
    columns=['cap-shape',
             'cap-surface',
             'cap-color',
             'bruises', 
             'odor', 
             'gill-spacing',
             'gill-size',
             'gill-color',
             'stalk-shape',
             'stalk-root',
             'stalk-surface-above-ring',
             'stalk-surface-below-ring',
             'stalk-color-above-ring',
             'stalk-color-below-ring',
             'ring-number',
             'ring-type',
             'spore-print-color',
             'population',
             'habitat'])
    
    delta = delta.loc[0]
    
    alg = A_C_N(C="AR", N="greedy")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
# Out:
#   0%|                                 | 1958/1632960 [04:14<58:58:06,  7.68it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#      27 delta = delta.loc[0]
#      29 alg = A_C_N(C="AR", N="greedy")
# ---> 31 depth, _ = alg.solve(S, delta=delta)
#      33 depths.append(depth)
#
# File ~/Desktop/DrDt/drdt/algorithms.py:82, in A_C_N.solve(self, S, delta)
#      79 # Step 2
#      80 else:
#      81     P_plus = SPlus(P)
# ---> 82     B = NGreedy(P_plus)
#      84     if len(B) == num_of_features:    # Checking, if they are same no need to run further
#      85         return num_of_features, "when we focus just depth"
#
# File ~/Desktop/DrDt/drdt/helper_functions.py:262, in NGreedy(S_plus)
#     260 if col in B:
#     261     continue  # Skip columns that have already been chosen
# --> 262 cover = S_max.index[S_max[col].notna()].intersection(uncovered_rows)
#     263 if len(cover) > max_cover:
#     264     max_cover = len(cover)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3304, in Index.intersection(self, other, sort)
#    3302 self._validate_sort_keyword(sort)
#    3303 self._assert_can_do_setop(other)
# -> 3304 other, result_name = self._convert_can_do_setop(other)
#    3306 if self.equals(other):
#    3307     if self.has_duplicates:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3568, in Index._convert_can_do_setop(self, other)
#    3565         other = Index(other, name=self.name, dtype=other.dtype)
#    3566     else:
#    3567         # e.g. list
# -> 3568         other = Index(other, name=self.name)
#    3569     result_name = self.name
#    3570 else:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:538, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     534     subarr = _maybe_cast_data_without_dtype(  # type: ignore[assignment]
#     535         subarr, cast_numeric_deprecated=False
#     536     )
#     537     dtype = subarr.dtype
# --> 538 return Index(subarr, dtype=dtype, copy=copy, name=name, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:483, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     475     data = data._values
#     477 if dtype is not None:
#     478     # we need to avoid having numpy coerce
#     479     # things that look like ints/floats to ints unless
#     480     # they are actually ints, e.g. '0' and 0.0
#     481     # should not be coerced
#     482     # GH 11836
# --> 483     data = sanitize_array(data, None, dtype=dtype, copy=copy)
#     485     dtype = data.dtype
#     487 if data.dtype.kind in ["i", "u", "f"]:
#     488     # maybe coerce to a sub-class
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/construction.py:567, in sanitize_array(data, index, dtype, copy, raise_cast_failure, allow_2d)
#     564             subarr = np.array(data, copy=copy)
#     565     else:
#     566         # we will try to copy by-definition here
# --> 567         subarr = _try_cast(data, dtype, copy, raise_cast_failure)
#     569 elif isinstance(data, ABCExtensionArray):
#     570     # it is already ensured above this is not a PandasArray
#     571     subarr = data
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/construction.py:776, in _try_cast(arr, dtype, copy, raise_cast_failure)
#     770 try:
#     771     # GH#15832: Check if we are requesting a numeric dtype and
#     772     # that we can convert the data to the requested dtype.
#     773     if is_integer_dtype(dtype):
#     774         # this will raise if we have e.g. floats
# --> 776         subarr = maybe_cast_to_integer_array(arr, dtype)
#     777     else:
#     778         # 4 tests fail if we move this to a try/except/else; see
#     779         #  test_constructor_compound_dtypes, test_constructor_cast_failure
#     780         #  test_constructor_dict_cast2, test_loc_setitem_dtype
#     781         subarr = np.array(arr, dtype=dtype, copy=copy)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:2040, in maybe_cast_to_integer_array(arr, dtype, copy)
#    2034 except OverflowError as err:
#    2035     raise OverflowError(
#    2036         "The elements provided in the data cannot all be "
#    2037         f"casted to the dtype {dtype}"
#    2038     ) from err
# -> 2040 if np.array_equal(arr, casted):
#    2041     return casted
#    2043 # We do this casting to allow for proper
#    2044 # data and dtype checking.
#    2045 #
#    2046 # We didn't do this earlier because NumPy
#    2047 # doesn't handle `uint64` correctly.
#
# File <__array_function__ internals>:5, in array_equal(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/numeric.py:2446, in array_equal(a1, a2, equal_nan)
#    2444     return False
#    2445 if not equal_nan:
# -> 2446     return bool(asarray(a1 == a2).all())
#    2447 # Handling NaN values if equal_nan is True
#    2448 a1nan, a2nan = isnan(a1), isnan(a2)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:63, in _all(a, axis, dtype, out, keepdims, where)
#      60 def _all(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
#      61     # Parsing keyword arguments is currently fairly slow, so avoid it for now
#      62     if where is True:
# ---> 63         return umr_all(a, axis, dtype, out, keepdims)
#      64     return umr_all(a, axis, dtype, out, keepdims, where=where)
#
# KeyboardInterrupt:

# %%
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
