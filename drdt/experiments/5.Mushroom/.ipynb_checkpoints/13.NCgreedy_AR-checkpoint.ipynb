# %%
import itertools
import pandas as pd
from importlib import resources
from tqdm import tqdm

from drdt.algorithms import A_C_N

# %%
with resources.path('datasets.DecisionRuleSystems', 'DRS_mushroom') as dataset_path:
    S = pd.read_csv(dataset_path)   
S
# Out:
#      cap-shape cap-surface cap-color bruises odor gill-spacing gill-size  \
# 0          NaN         NaN       NaN     NaN    p          NaN       NaN
# 1          NaN         NaN       NaN     NaN    a          NaN       NaN
# 2          NaN         NaN       NaN     NaN    l          NaN       NaN
# 3          NaN         NaN       NaN     NaN    p          NaN       NaN
# 4          NaN         NaN       NaN     NaN  NaN          NaN       NaN
# ...        ...         ...       ...     ...  ...          ...       ...
# 8119       NaN         NaN       NaN     NaN    n          NaN       NaN
# 8120       NaN         NaN       NaN     NaN    n          NaN       NaN
# 8121         f         NaN       NaN     NaN  NaN          NaN       NaN
# 8122         k         NaN       NaN     NaN  NaN          NaN       NaN
# 8123       NaN         NaN       NaN       f  NaN          NaN       NaN
#
#      gill-color stalk-shape stalk-root stalk-surface-above-ring  \
# 0           NaN         NaN        NaN                      NaN
# 1           NaN         NaN        NaN                      NaN
# 2           NaN         NaN        NaN                      NaN
# 3           NaN         NaN        NaN                      NaN
# 4           NaN         NaN        NaN                      NaN
# ...         ...         ...        ...                      ...
# 8119        NaN         NaN        NaN                      NaN
# 8120        NaN         NaN        NaN                      NaN
# 8121        NaN         NaN        NaN                      NaN
# 8122        NaN         NaN        NaN                      NaN
# 8123        NaN         NaN        NaN                      NaN
#
#      stalk-color-above-ring stalk-color-below-ring spore-print-color  \
# 0                       NaN                    NaN               NaN
# 1                       NaN                    NaN               NaN
# 2                       NaN                    NaN               NaN
# 3                       NaN                    NaN               NaN
# 4                       NaN                    NaN               NaN
# ...                     ...                    ...               ...
# 8119                    NaN                    NaN               NaN
# 8120                    NaN                    NaN               NaN
# 8121                    NaN                    NaN               NaN
# 8122                    NaN                    NaN               NaN
# 8123                    NaN                    NaN               NaN
#
#      population class
# 0           NaN     p
# 1           NaN     e
# 2           NaN     e
# 3           NaN     p
# 4             a     e
# ...         ...   ...
# 8119        NaN     e
# 8120        NaN     e
# 8121        NaN     e
# 8122        NaN     p
# 8123        NaN     e
#
# [8124 rows x 16 columns]

# %%
res = 1

for col in S.columns[:-1]:
    res *= len(S[col].unique())-1
    
print("number of possible combinations =", res)
# Out:
# number of possible combinations = 272160

# %%
# Possible values for each featue
cap_shape_values = ['s', 'f', 'b', 'x', 'c', 'k']
cap_surface_values = ['f', 'y', 'g']
cap_color_values = ['g', 'n', 'e', 'w', 'y', 'u', 'c', 'r', 'b', 'p']
bruises_values = ['f', 't'] 
odor_values = ['p', 'a', 'l', 'n', 'f', 'c', 'y', 's', 'm']
gill_spacing_values = ['w']
gill_size_values = ['b', 'n']
gill_color_values = ['k', 'n', 'p', 'u', 'e', 'r', 'o']
stalk_shape_values = ['t']
stalk_root_values = ['e', 'b']
stalk_surface_above_ring_values = ['f']
stalk_color_above_ring_values = ['g']
stalk_color_below_ring_values = ['g']
spore_print_color_values = ['n', 'k', 'r']
population_values = ['a']


# All possible combinations
combinations = list(itertools.product(cap_shape_values, 
                                      cap_surface_values, 
                                      cap_color_values, 
                                      bruises_values, 
                                      odor_values, 
                                      gill_spacing_values,
                                      gill_size_values,
                                      gill_color_values,
                                      stalk_shape_values,
                                      stalk_root_values,
                                      stalk_surface_above_ring_values,
                                      stalk_color_above_ring_values,
                                      stalk_color_below_ring_values,
                                      spore_print_color_values,
                                      population_values))

# %%
depths = []

for comb in tqdm(combinations):
    #creating delta
    delta = pd.DataFrame(
    [[comb[0], comb[1], comb[2], comb[3], comb[4], comb[5], comb[6], comb[7], comb[8], comb[9], comb[10], comb[11], comb[12], comb[13], comb[14]]],
    columns=['cap-shape',
             'cap-surface',
             'cap-color',
             'bruises', 
             'odor', 
             'gill-spacing',
             'gill-size',
             'gill-color',
             'stalk-shape',
             'stalk-root',
             'stalk-surface-above-ring',
             'stalk-color-above-ring',
             'stalk-color-below-ring',
             'spore-print-color',
             'population'])
    
    delta = delta.loc[0]
    
    alg = A_C_N(C="AR", N="greedy")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
# Out:
#   1%|▏                                  | 1436/272160 [02:32<8:00:38,  9.39it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#      23 delta = delta.loc[0]
#      25 alg = A_C_N(C="AR", N="greedy")
# ---> 27 depth, _ = alg.solve(S, delta=delta)
#      29 depths.append(depth)
#
# File ~/Desktop/DrDt/drdt/algorithms.py:82, in A_C_N.solve(self, S, delta)
#      79 # Step 2
#      80 else:
#      81     P_plus = SPlus(P)
# ---> 82     B = NGreedy(P_plus)
#      84     if len(B) == num_of_features:    # Checking, if they are same no need to run further
#      85         return num_of_features, "when we focus just depth"
#
# File ~/Desktop/DrDt/drdt/helper_functions.py:249, in NGreedy(S_plus)
#     244 def NGreedy(S_plus):
#     245     """
#     246     input: S_plus - subset of S as defined in the paper. (pandas DataFrame)
#     247     output: Node cover of S_plus, set of indecies of columns that covers all rows
#     248     """
# --> 249     S_max = SMax(S_plus)
#     251     B = set()
#     252     uncovered_rows = set(S_max.index)
#
# File ~/Desktop/DrDt/drdt/helper_functions.py:114, in SMax(S_plus)
#     107 """
#     108 input: S_plus - system of decision rules with length d (pandas DataFrame)
#     109 output: S_max - subset of S as defined in the paper. (pandas DataFrame)
#     110 """
#     112 columns_to_check = S_plus.columns[:-1]
# --> 114 S_max = S_plus.drop_duplicates(subset=columns_to_check, keep='first')
#     116 return S_max
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:6116, in DataFrame.drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6114 inplace = validate_bool_kwarg(inplace, "inplace")
#    6115 ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
# -> 6116 duplicated = self.duplicated(subset, keep=keep)
#    6118 result = self[-duplicated]
#    6119 if ignore_index:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:6248, in DataFrame.duplicated(self, subset, keep)
#    6243 subset = cast(Sequence, subset)
#    6245 # Verify all columns in subset exist in the queried dataframe
#    6246 # Otherwise, raise a KeyError, same as if you try to __getitem__ with a
#    6247 # key that doesn't exist.
# -> 6248 diff = Index(subset).difference(self.columns)
#    6249 if not diff.empty:
#    6250     raise KeyError(diff)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3448, in Index.difference(self, other, sort)
#    3444 if not self._should_compare(other):
#    3445     # Nothing matches -> difference is everything
#    3446     return self.rename(result_name)
# -> 3448 result = self._difference(other, sort=sort)
#    3449 return self._wrap_difference_result(other, result)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3456, in Index._difference(self, other, sort)
#    3451 def _difference(self, other, sort):
#    3452     # overridden by RangeIndex
#    3454     this = self.unique()
# -> 3456     indexer = this.get_indexer_for(other)
#    3457     indexer = indexer.take((indexer != -1).nonzero()[0])
#    3459     label_diff = np.setdiff1d(np.arange(this.size), indexer, assume_unique=True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5764, in Index.get_indexer_for(self, target)
#    5746 """
#    5747 Guaranteed return of an indexer even when non-unique.
#    5748
#    (...)
#    5761 array([0, 2])
#    5762 """
#    5763 if self._index_as_unique:
# -> 5764     return self.get_indexer(target)
#    5765 indexer, _ = self.get_indexer_non_unique(target)
#    5766 return indexer
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3772, in Index.get_indexer(self, target, method, limit, tolerance)
#    3768 if is_dtype_equal(self.dtype, target.dtype) and self.equals(target):
#    3769     # Only call equals if we have same dtype to avoid inference/casting
#    3770     return np.arange(len(target), dtype=np.intp)
# -> 3772 if not is_dtype_equal(self.dtype, target.dtype) and not is_interval_dtype(
#    3773     self.dtype
#    3774 ):
#    3775     # IntervalIndex gets special treatment for partial-indexing
#    3776     dtype = self._find_common_type_compat(target)
#    3778     this = self.astype(dtype, copy=False)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/common.py:618, in is_dtype_equal(source, target)
#     616         except (TypeError, AttributeError, ImportError):
#     617             return False
# --> 618 elif isinstance(source, str):
#     619     return is_dtype_equal(target, source)
#     621 try:
#
# KeyboardInterrupt:

# %%
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
