# %%
import itertools
import pandas as pd
from importlib import resources
from tqdm import tqdm

from drdt.algorithms import A_C_N

# %%
with resources.path('datasets.DecisionRuleSystems', 'DRS_mushroom') as dataset_path:
    S = pd.read_csv(dataset_path)   
S
# Out:
#      cap-shape cap-surface cap-color bruises odor gill-spacing gill-size  \
# 0          NaN         NaN       NaN     NaN    p          NaN       NaN
# 1          NaN         NaN       NaN     NaN    a          NaN       NaN
# 2          NaN         NaN       NaN     NaN    l          NaN       NaN
# 3          NaN         NaN       NaN     NaN    p          NaN       NaN
# 4          NaN         NaN       NaN     NaN  NaN          NaN       NaN
# ...        ...         ...       ...     ...  ...          ...       ...
# 8119       NaN         NaN       NaN     NaN    n          NaN       NaN
# 8120       NaN         NaN       NaN     NaN    n          NaN       NaN
# 8121         f         NaN       NaN     NaN  NaN          NaN       NaN
# 8122         k         NaN       NaN     NaN  NaN          NaN       NaN
# 8123       NaN         NaN       NaN       f  NaN          NaN       NaN
#
#      gill-color stalk-shape stalk-root stalk-surface-above-ring  \
# 0           NaN         NaN        NaN                      NaN
# 1           NaN         NaN        NaN                      NaN
# 2           NaN         NaN        NaN                      NaN
# 3           NaN         NaN        NaN                      NaN
# 4           NaN         NaN        NaN                      NaN
# ...         ...         ...        ...                      ...
# 8119        NaN         NaN        NaN                      NaN
# 8120        NaN         NaN        NaN                      NaN
# 8121        NaN         NaN        NaN                      NaN
# 8122        NaN         NaN        NaN                      NaN
# 8123        NaN         NaN        NaN                      NaN
#
#      stalk-color-above-ring stalk-color-below-ring spore-print-color  \
# 0                       NaN                    NaN               NaN
# 1                       NaN                    NaN               NaN
# 2                       NaN                    NaN               NaN
# 3                       NaN                    NaN               NaN
# 4                       NaN                    NaN               NaN
# ...                     ...                    ...               ...
# 8119                    NaN                    NaN               NaN
# 8120                    NaN                    NaN               NaN
# 8121                    NaN                    NaN               NaN
# 8122                    NaN                    NaN               NaN
# 8123                    NaN                    NaN               NaN
#
#      population class
# 0           NaN     p
# 1           NaN     e
# 2           NaN     e
# 3           NaN     p
# 4             a     e
# ...         ...   ...
# 8119        NaN     e
# 8120        NaN     e
# 8121        NaN     e
# 8122        NaN     p
# 8123        NaN     e
#
# [8124 rows x 16 columns]

# %%
res = 1

for col in S.columns[:-1]:
    res *= len(S[col].unique())-1
    
print("number of possible combinations =", res)
# Out:
# number of possible combinations = 272160

# %%
# Possible values for each featue
cap_shape_values = ['s', 'f', 'b', 'x', 'c', 'k']
cap_surface_values = ['f', 'y', 'g']
cap_color_values = ['g', 'n', 'e', 'w', 'y', 'u', 'c', 'r', 'b', 'p']
bruises_values = ['f', 't'] 
odor_values = ['p', 'a', 'l', 'n', 'f', 'c', 'y', 's', 'm']
gill_spacing_values = ['w']
gill_size_values = ['b', 'n']
gill_color_values = ['k', 'n', 'p', 'u', 'e', 'r', 'o']
stalk_shape_values = ['t']
stalk_root_values = ['e', 'b']
stalk_surface_above_ring_values = ['f']
stalk_color_above_ring_values = ['g']
stalk_color_below_ring_values = ['g']
spore_print_color_values = ['n', 'k', 'r']
population_values = ['a']


# All possible combinations
combinations = list(itertools.product(cap_shape_values, 
                                      cap_surface_values, 
                                      cap_color_values, 
                                      bruises_values, 
                                      odor_values, 
                                      gill_spacing_values,
                                      gill_size_values,
                                      gill_color_values,
                                      stalk_shape_values,
                                      stalk_root_values,
                                      stalk_surface_above_ring_values,
                                      stalk_color_above_ring_values,
                                      stalk_color_below_ring_values,
                                      spore_print_color_values,
                                      population_values))

# %%
depths = []

for comb in tqdm(combinations):
    #creating delta
    delta = pd.DataFrame(
    [[comb[0], comb[1], comb[2], comb[3], comb[4], comb[5], comb[6], comb[7], comb[8], comb[9], comb[10], comb[11], comb[12], comb[13], comb[14]]],
    columns=['cap-shape',
             'cap-surface',
             'cap-color',
             'bruises', 
             'odor', 
             'gill-spacing',
             'gill-size',
             'gill-color',
             'stalk-shape',
             'stalk-root',
             'stalk-surface-above-ring',
             'stalk-color-above-ring',
             'stalk-color-below-ring',
             'spore-print-color',
             'population'])
    
    delta = delta.loc[0]
    
    alg = A_C_N(C="AR", N="cover")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
# Out:
#   6%|█▋                             | 14994/272160 [3:03:09<52:21:28,  1.36it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#      23 delta = delta.loc[0]
#      25 alg = A_C_N(C="AR", N="cover")
# ---> 27 depth, _ = alg.solve(S, delta=delta)
#      29 depths.append(depth)
#
# File ~/Desktop/DrDt/drdt/algorithms.py:55, in A_C_N.solve(self, S, delta)
#      52 # Step 2
#      53 else:
#      54     P_plus = SPlus(P)
# ---> 55     B = NCover(P_plus)
#      57     if len(B) == num_of_features:    # Checking, if they are same no need to run further
#      58         return num_of_features, "when we focus just depth"
#
# File ~/Desktop/DrDt/drdt/helper_functions.py:234, in NCover(S_plus)
#     232 rows_to_drop = []
#     233 for index, row in S_plus.iterrows():
# --> 234     row = row[:-1]
#     235     A_r = set(row[row.notna()].index)
#     236     if A_r1 & A_r:  # Check for common elements
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:984, in Series.__getitem__(self, key)
#     981     key = np.asarray(key, dtype=bool)
#     982     return self._get_values(key)
# --> 984 return self._get_with(key)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:992, in Series._get_with(self, key)
#     988 if isinstance(key, slice):
#     989     # _convert_slice_indexer to determine if this slice is positional
#     990     #  or label based, and if the latter, convert to positional
#     991     slobj = self.index._convert_slice_indexer(key, kind="getitem")
# --> 992     return self._slice(slobj)
#     993 elif isinstance(key, ABCDataFrame):
#     994     raise TypeError(
#     995         "Indexing a Series with DataFrame is not "
#     996         "supported, use the appropriate DataFrame column"
#     997     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:941, in Series._slice(self, slobj, axis)
#     938 def _slice(self, slobj: slice, axis: int = 0) -> Series:
#     939     # axis kwarg is retained for compat with NDFrame method
#     940     #  _slice is *always* positional
# --> 941     return self._get_values(slobj)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:1044, in Series._get_values(self, indexer)
#    1042 def _get_values(self, indexer):
#    1043     try:
# -> 1044         new_mgr = self._mgr.getitem_mgr(indexer)
#    1045         return self._constructor(new_mgr).__finalize__(self)
#    1046     except ValueError:
#    1047         # mpl compat if we look up e.g. ser[:, np.newaxis];
#    1048         #  see tests.series.timeseries.test_mpl_compat_hack
#    1049         # the asarray is needed to avoid returning a 2D DatetimeArray
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py:1817, in SingleBlockManager.getitem_mgr(self, indexer)
#    1814 bp = BlockPlacement(slice(0, len(array)))
#    1815 block = type(blk)(array, placement=bp, ndim=1)
# -> 1817 new_idx = self.index[indexer]
#    1818 return type(self)(block, new_idx)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5036, in Index.__getitem__(self, key)
#    5024 """
#    5025 Override numpy.ndarray's __getitem__ method to work as desired.
#    5026
#    (...)
#    5032
#    5033 """
#    5034 getitem = self._data.__getitem__
# -> 5036 if is_integer(key) or is_float(key):
#    5037     # GH#44051 exclude bool, which would return a 2d ndarray
#    5038     key = com.cast_scalar_indexer(key, warn_float=True)
#    5039     return getitem(key)
#
# KeyboardInterrupt:

# %%
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
