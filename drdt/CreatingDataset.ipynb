# %% [markdown]
# # Creating Decision Rule Systems

# %%
import pandas as pd
from helper_functions import DecisionRuleCreatorFromDecisionTable

# %% [markdown]
# # Tic Tac Toe

# %%
DecisionTable = pd.read_csv("./Datasets/UCIMLDatasets/tic-tac-toe.csv", header=None)

DecisionTable.columns = ["top-left-square", "top-middle-square", "top-right-square", "middle-left-square", "middle-middle-square", "middle-right-square", "bottom-left-square", "bottom-middle-square", "bottom-right-square", "class"]

# %%
DecisionTable
# Out:
#     top-left-square top-middle-square top-right-square middle-left-square  \
# 0                 x                 x                x                  x
# 1                 x                 x                x                  x
# 2                 x                 x                x                  x
# 3                 x                 x                x                  x
# 4                 x                 x                x                  x
# ..              ...               ...              ...                ...
# 953               o                 x                x                  x
# 954               o                 x                o                  x
# 955               o                 x                o                  x
# 956               o                 x                o                  o
# 957               o                 o                x                  x
#
#     middle-middle-square middle-right-square bottom-left-square  \
# 0                      o                   o                  x
# 1                      o                   o                  o
# 2                      o                   o                  o
# 3                      o                   o                  o
# 4                      o                   o                  b
# ..                   ...                 ...                ...
# 953                    o                   o                  o
# 954                    x                   o                  x
# 955                    o                   x                  x
# 956                    x                   x                  x
# 957                    x                   o                  o
#
#     bottom-middle-square bottom-right-square     class
# 0                      o                   o  positive
# 1                      x                   o  positive
# 2                      o                   x  positive
# 3                      b                   b  positive
# 4                      o                   b  positive
# ..                   ...                 ...       ...
# 953                    x                   x  negative
# 954                    o                   x  negative
# 955                    o                   x  negative
# 956                    o                   x  negative
# 957                    x                   x  negative
#
# [958 rows x 10 columns]

# %%
DecisionRule = DecisionRuleCreatorFromDecisionTable(DecisionTable)
# Out:
# 100%|████████████████████████████████████████| 958/958 [00:02<00:00, 420.67it/s]

# %%
DecisionRule
# Out:
#     top-left-square top-middle-square top-right-square middle-left-square  \
# 0               NaN               NaN              NaN                NaN
# 1               NaN               NaN              NaN                NaN
# 2               NaN               NaN              NaN                NaN
# 3               NaN               NaN                x                NaN
# 4               NaN                 x              NaN                  x
# ..              ...               ...              ...                ...
# 953               o               NaN              NaN                NaN
# 954             NaN               NaN                o                  x
# 955               o               NaN              NaN                NaN
# 956               o               NaN              NaN                NaN
# 957               o               NaN              NaN                NaN
#
#     middle-middle-square middle-right-square bottom-left-square  \
# 0                      o                   o                NaN
# 1                      o                   o                  o
# 2                      o                   o                  o
# 3                    NaN                   o                  o
# 4                    NaN                 NaN                  b
# ..                   ...                 ...                ...
# 953                  NaN                 NaN                NaN
# 954                  NaN                 NaN                NaN
# 955                  NaN                   x                NaN
# 956                  NaN                   x                NaN
# 957                  NaN                 NaN                NaN
#
#     bottom-middle-square bottom-right-square     class
# 0                      o                   o  positive
# 1                    NaN                   o  positive
# 2                      o                 NaN  positive
# 3                    NaN                   b  positive
# 4                    NaN                   b  positive
# ..                   ...                 ...       ...
# 953                    x                 NaN  negative
# 954                  NaN                 NaN  negative
# 955                  NaN                 NaN  negative
# 956                  NaN                 NaN  negative
# 957                    x                 NaN  negative
#
# [958 rows x 10 columns]

# %%
DecisionRule.to_csv('./Datasets/DecisionRuleSystems/DRS_tic-tac-toe', index=False)

# %% [markdown]
# # Car Evaluation

# %%
DecisionTable = pd.read_csv("./Datasets/UCIMLDatasets/car_evaluation.csv", header=None)

DecisionTable.columns = ["buying", "maint", "doors", "persons", "lug_boot", "safety", "class"]

# %%
DecisionTable
# Out:
#      buying  maint  doors persons lug_boot safety  class
# 0     vhigh  vhigh      2       2    small    low  unacc
# 1     vhigh  vhigh      2       2    small    med  unacc
# 2     vhigh  vhigh      2       2    small   high  unacc
# 3     vhigh  vhigh      2       2      med    low  unacc
# 4     vhigh  vhigh      2       2      med    med  unacc
# ...     ...    ...    ...     ...      ...    ...    ...
# 1723    low    low  5more    more      med    med   good
# 1724    low    low  5more    more      med   high  vgood
# 1725    low    low  5more    more      big    low  unacc
# 1726    low    low  5more    more      big    med   good
# 1727    low    low  5more    more      big   high  vgood
#
# [1728 rows x 7 columns]

# %%
DecisionRule = DecisionRuleCreatorFromDecisionTable(DecisionTable)
# Out:
# 100%|██████████████████████████████████████| 1728/1728 [00:03<00:00, 459.43it/s]

# %%
DecisionRule.to_csv('./Datasets/DecisionRuleSystems/DRS_car_evaluation', index=False)

# %% [markdown]
# # Mushroom Dataset

# %%
#pip install ucimlrepo
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
mushroom = fetch_ucirepo(id=73) 
  
# data (as pandas dataframes) 
X = mushroom.data.features 
y = mushroom.data.targets 

#rename target name 'poisonous' to 'class'
y = y.rename(columns={'poisonous': 'class'})

# %%
DecisionTable = pd.concat([X, y], axis=1)

# %%
DecisionTable
# Out:
#      cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0            x           s         n       t    p               f
# 1            x           s         y       t    a               f
# 2            b           s         w       t    l               f
# 3            x           y         w       t    p               f
# 4            x           s         g       f    n               f
# ...        ...         ...       ...     ...  ...             ...
# 8119         k           s         n       f    n               a
# 8120         x           s         n       f    n               a
# 8121         f           s         n       f    n               a
# 8122         k           y         n       f    y               f
# 8123         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# 0               c         n          k           e  ...
# 1               c         b          k           e  ...
# 2               c         b          n           e  ...
# 3               c         n          n           e  ...
# 4               w         b          k           t  ...
# ...           ...       ...        ...         ...  ...
# 8119            c         b          y           e  ...
# 8120            c         b          y           e  ...
# 8121            c         b          n           e  ...
# 8122            c         n          b           t  ...
# 8123            c         b          y           e  ...
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                         w                      w         p          w
# 1                         w                      w         p          w
# 2                         w                      w         p          w
# 3                         w                      w         p          w
# 4                         w                      w         p          w
# ...                     ...                    ...       ...        ...
# 8119                      o                      o         p          o
# 8120                      o                      o         p          n
# 8121                      o                      o         p          o
# 8122                      w                      w         p          w
# 8123                      o                      o         p          o
#
#      ring-number ring-type spore-print-color population habitat class
# 0              o         p                 k          s       u     p
# 1              o         p                 n          n       g     e
# 2              o         p                 n          n       m     e
# 3              o         p                 k          s       u     p
# 4              o         e                 n          a       g     e
# ...          ...       ...               ...        ...     ...   ...
# 8119           o         p                 b          c       l     e
# 8120           o         p                 b          v       l     e
# 8121           o         p                 b          c       l     e
# 8122           o         e                 w          v       l     p
# 8123           o         p                 o          c       l     e
#
# [8124 rows x 23 columns]

# %%
DecisionRule = DecisionRuleCreatorFromDecisionTable(DecisionTable)
# Out:
#   0%|                                                  | 0/8124 [00:00<?, ?it/s]/Users/durdymk/Desktop/DR-DT/helper_functions.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   r[mask_row] = np.nan
# 100%|███████████████████████████████████████| 8124/8124 [03:27<00:00, 39.10it/s]

# %%
DecisionRule
# Out:
#      cap-shape cap-surface cap-color bruises odor gill-spacing gill-size  \
# 0          NaN         NaN       NaN     NaN    p          NaN       NaN
# 1          NaN         NaN       NaN     NaN    a          NaN       NaN
# 2          NaN         NaN       NaN     NaN    l          NaN       NaN
# 3          NaN         NaN       NaN     NaN    p          NaN       NaN
# 4          NaN         NaN       NaN     NaN  NaN          NaN       NaN
# ...        ...         ...       ...     ...  ...          ...       ...
# 8119       NaN         NaN       NaN     NaN    n          NaN       NaN
# 8120       NaN         NaN       NaN     NaN    n          NaN       NaN
# 8121         f         NaN       NaN     NaN  NaN          NaN       NaN
# 8122         k         NaN       NaN     NaN  NaN          NaN       NaN
# 8123       NaN         NaN       NaN       f  NaN          NaN       NaN
#
#      gill-color stalk-shape stalk-root stalk-surface-above-ring  \
# 0           NaN         NaN        NaN                      NaN
# 1           NaN         NaN        NaN                      NaN
# 2           NaN         NaN        NaN                      NaN
# 3           NaN         NaN        NaN                      NaN
# 4           NaN         NaN        NaN                      NaN
# ...         ...         ...        ...                      ...
# 8119        NaN         NaN        NaN                      NaN
# 8120        NaN         NaN        NaN                      NaN
# 8121        NaN         NaN        NaN                      NaN
# 8122        NaN         NaN        NaN                      NaN
# 8123        NaN         NaN        NaN                      NaN
#
#      stalk-color-above-ring stalk-color-below-ring spore-print-color  \
# 0                       NaN                    NaN               NaN
# 1                       NaN                    NaN               NaN
# 2                       NaN                    NaN               NaN
# 3                       NaN                    NaN               NaN
# 4                       NaN                    NaN               NaN
# ...                     ...                    ...               ...
# 8119                    NaN                    NaN               NaN
# 8120                    NaN                    NaN               NaN
# 8121                    NaN                    NaN               NaN
# 8122                    NaN                    NaN               NaN
# 8123                    NaN                    NaN               NaN
#
#      population class
# 0           NaN     p
# 1           NaN     e
# 2           NaN     e
# 3           NaN     p
# 4             a     e
# ...         ...   ...
# 8119        NaN     e
# 8120        NaN     e
# 8121        NaN     e
# 8122        NaN     p
# 8123        NaN     e
#
# [8124 rows x 16 columns]

# %%
DecisionRule.to_csv('./Datasets/DecisionRuleSystems/DRS_mushroom', index=False)

# %% [markdown]
# # Congressional Voting Records

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset 
congressional_voting_records = fetch_ucirepo(id=105) 
  
# data (as pandas dataframes) 
X = congressional_voting_records.data.features 
y = congressional_voting_records.data.targets 

#rename target name 'Class' to 'class'
y = y.rename(columns={'Class': 'class'})

# %%
DecisionTable = pd.concat([X, y], axis=1)

# %%
DecisionTable
# Out:
#     handicapped-infants water-project-cost-sharing  \
# 0                     n                          y
# 1                     n                          y
# 2                   NaN                          y
# 3                     n                          y
# 4                     y                          y
# ..                  ...                        ...
# 430                   n                          n
# 431                   n                          n
# 432                   n                        NaN
# 433                   n                          n
# 434                   n                          y
#
#     adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                   n                    y               y
# 1                                   n                    y               y
# 2                                   y                  NaN               y
# 3                                   y                    n             NaN
# 4                                   y                    n               y
# ..                                ...                  ...             ...
# 430                                 y                    y               y
# 431                                 y                    n               n
# 432                                 n                    y               y
# 433                                 n                    y               y
# 434                                 n                    y               y
#
#     religious-groups-in-schools anti-satellite-test-ban  \
# 0                             y                       n
# 1                             y                       n
# 2                             y                       n
# 3                             y                       n
# 4                             y                       n
# ..                          ...                     ...
# 430                           y                       n
# 431                           n                       y
# 432                           y                       n
# 433                           y                     NaN
# 434                           y                       n
#
#     aid-to-nicaraguan-contras mx-missile immigration  \
# 0                           n          n           y
# 1                           n          n           n
# 2                           n          n           n
# 3                           n          n           n
# 4                           n          n           n
# ..                        ...        ...         ...
# 430                         n          y           y
# 431                         y          y           y
# 432                         n          n           n
# 433                       NaN        NaN         NaN
# 434                         n          n           y
#
#     synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 0                            NaN                  y                      y
# 1                              n                  y                      y
# 2                              y                  n                      y
# 3                              y                  n                      y
# 4                              y                NaN                      y
# ..                           ...                ...                    ...
# 430                            n                  y                      y
# 431                            n                  n                      n
# 432                            y                  y                      y
# 433                            n                  y                      y
# 434                            n                  y                      y
#
#     crime duty-free-exports export-administration-act-south-africa       class
# 0       y                 n                                      y  republican
# 1       y                 n                                    NaN  republican
# 2       y                 n                                      n    democrat
# 3       n                 n                                      y    democrat
# 4       y                 y                                      y    democrat
# ..    ...               ...                                    ...         ...
# 430     y                 n                                      y  republican
# 431     n                 n                                      y    democrat
# 432     y                 n                                      y  republican
# 433     y                 n                                      y  republican
# 434     y               NaN                                      n  republican
#
# [435 rows x 17 columns]

# %%
DecisionRule = DecisionRuleCreatorFromDecisionTable(DecisionTable)
# Out:
#   0%|                                                   | 0/435 [00:00<?, ?it/s]/Users/durdymk/Desktop/DR-DT/helper_functions.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   r[mask_row] = np.nan
# 100%|████████████████████████████████████████| 435/435 [00:01<00:00, 307.23it/s]

# %%
DecisionRule
# Out:
#     handicapped-infants water-project-cost-sharing  \
# 0                   NaN                        NaN
# 1                   NaN                        NaN
# 2                   NaN                        NaN
# 3                   NaN                        NaN
# 4                   NaN                        NaN
# ..                  ...                        ...
# 430                 NaN                        NaN
# 431                 NaN                        NaN
# 432                 NaN                        NaN
# 433                 NaN                          n
# 434                 NaN                        NaN
#
#     adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                 NaN                  NaN             NaN
# 1                                 NaN                  NaN             NaN
# 2                                 NaN                  NaN             NaN
# 3                                 NaN                  NaN             NaN
# 4                                 NaN                  NaN             NaN
# ..                                ...                  ...             ...
# 430                               NaN                    y             NaN
# 431                               NaN                    n             NaN
# 432                               NaN                  NaN             NaN
# 433                               NaN                  NaN             NaN
# 434                                 n                  NaN             NaN
#
#     religious-groups-in-schools anti-satellite-test-ban mx-missile  \
# 0                           NaN                     NaN        NaN
# 1                           NaN                     NaN        NaN
# 2                           NaN                     NaN        NaN
# 3                           NaN                     NaN        NaN
# 4                           NaN                     NaN        NaN
# ..                          ...                     ...        ...
# 430                         NaN                     NaN        NaN
# 431                         NaN                     NaN        NaN
# 432                         NaN                     NaN        NaN
# 433                         NaN                     NaN        NaN
# 434                         NaN                     NaN        NaN
#
#     immigration synfuels-corporation-cutback education-spending  \
# 0           NaN                          NaN                NaN
# 1           NaN                          NaN                NaN
# 2           NaN                          NaN                NaN
# 3           NaN                          NaN                NaN
# 4           NaN                          NaN                NaN
# ..          ...                          ...                ...
# 430         NaN                          NaN                NaN
# 431         NaN                          NaN                NaN
# 432         NaN                          NaN                NaN
# 433         NaN                          NaN                NaN
# 434         NaN                          NaN                NaN
#
#     superfund-right-to-sue crime duty-free-exports  \
# 0                      NaN   NaN               NaN
# 1                      NaN   NaN               NaN
# 2                      NaN   NaN               NaN
# 3                      NaN   NaN               NaN
# 4                      NaN   NaN               NaN
# ..                     ...   ...               ...
# 430                    NaN   NaN               NaN
# 431                    NaN   NaN               NaN
# 432                    NaN   NaN               NaN
# 433                    NaN   NaN               NaN
# 434                    NaN   NaN               NaN
#
#     export-administration-act-south-africa       class
# 0                                      NaN  republican
# 1                                      NaN  republican
# 2                                      NaN    democrat
# 3                                      NaN    democrat
# 4                                      NaN    democrat
# ..                                     ...         ...
# 430                                    NaN  republican
# 431                                    NaN    democrat
# 432                                    NaN  republican
# 433                                    NaN  republican
# 434                                    NaN  republican
#
# [435 rows x 16 columns]

# %%
DecisionRule.to_csv('./Datasets/DecisionRuleSystems/DRS_congressional_voting_records', index=False)

# %% [markdown]
# # Breast Cancer

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
breast_cancer = fetch_ucirepo(id=14) 
  
# data (as pandas dataframes) 
X = breast_cancer.data.features 
y = breast_cancer.data.targets 

#rename target name 'Class' to 'class'
y = y.rename(columns={'Class': 'class'})

# %%
DecisionTable = pd.concat([X, y], axis=1)

# %%
DecisionTable
# Out:
#        age menopause tumor-size inv-nodes node-caps  deg-malig breast  \
# 0    30-39   premeno      30-34       0-2        no          3   left
# 1    40-49   premeno      20-24       0-2        no          2  right
# 2    40-49   premeno      20-24       0-2        no          2   left
# 3    60-69      ge40      15-19       0-2        no          2  right
# 4    40-49   premeno        0-4       0-2        no          2  right
# ..     ...       ...        ...       ...       ...        ...    ...
# 281  30-39   premeno      30-34       0-2        no          2   left
# 282  30-39   premeno      20-24       0-2        no          3   left
# 283  60-69      ge40      20-24       0-2        no          1  right
# 284  40-49      ge40      30-34     5-Mar        no          3   left
# 285  50-59      ge40      30-34     5-Mar        no          3   left
#
#     breast-quad irradiat                 class
# 0      left_low       no  no-recurrence-events
# 1      right_up       no  no-recurrence-events
# 2      left_low       no  no-recurrence-events
# 3       left_up       no  no-recurrence-events
# 4     right_low       no  no-recurrence-events
# ..          ...      ...                   ...
# 281     left_up       no     recurrence-events
# 282     left_up      yes     recurrence-events
# 283     left_up       no     recurrence-events
# 284    left_low       no     recurrence-events
# 285    left_low       no     recurrence-events
#
# [286 rows x 10 columns]

# %%
DecisionRule = DecisionRuleCreatorFromDecisionTable(DecisionTable)
# Out:
#   0%|                                                   | 0/286 [00:00<?, ?it/s]/Users/durdymk/Desktop/DR-DT/helper_functions.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   r[mask_row] = np.nan
# 100%|████████████████████████████████████████| 286/286 [00:02<00:00, 142.85it/s]

# %%
DecisionRule
# Out:
#        age menopause tumor-size inv-nodes node-caps  deg-malig breast  \
# 0    30-39       NaN      30-34       NaN       NaN        NaN    NaN
# 1      NaN       NaN      20-24       0-2       NaN        NaN    NaN
# 2    40-49   premeno      20-24       0-2        no        2.0   left
# 3    60-69       NaN      15-19       NaN       NaN        NaN    NaN
# 4    40-49       NaN        0-4       NaN       NaN        NaN    NaN
# ..     ...       ...        ...       ...       ...        ...    ...
# 281  30-39   premeno      30-34       0-2        no        2.0   left
# 282  30-39       NaN      20-24       NaN       NaN        3.0    NaN
# 283  60-69       NaN      20-24       NaN       NaN        1.0  right
# 284    NaN       NaN      30-34     5-Mar        no        NaN    NaN
# 285    NaN       NaN      30-34     5-Mar        no        NaN    NaN
#
#     breast-quad irradiat                 class
# 0      left_low      NaN  no-recurrence-events
# 1      right_up      NaN  no-recurrence-events
# 2      left_low       no  no-recurrence-events
# 3           NaN      NaN  no-recurrence-events
# 4           NaN      NaN  no-recurrence-events
# ..          ...      ...                   ...
# 281     left_up       no     recurrence-events
# 282     left_up      NaN     recurrence-events
# 283         NaN      NaN     recurrence-events
# 284         NaN      NaN     recurrence-events
# 285         NaN      NaN     recurrence-events
#
# [286 rows x 10 columns]

# %%
DecisionRule.to_csv('./Datasets/DecisionRuleSystems/DRS_breast_cancer', index=False)

# %% [markdown]
# # Example

# %%
example_DTable = pd.DataFrame(
[[1,1,1,1],
[0,1,0,2],
[1,1,0,2],
[0,0,1,3],
[1,0,0,3]],
columns=['f1','f2','f3','class']
)
example_DTable
# Out:
#    f1  f2  f3  class
# 0   1   1   1      1
# 1   0   1   0      2
# 2   1   1   0      2
# 3   0   0   1      3
# 4   1   0   0      3

# %%
example_DRules = DecisionRuleCreatorFromDecisionTable(example_DTable)
example_DRules
# Out:
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 930.70it/s]
#     f1   f2   f3  class
# 0  1.0  NaN  1.0      1
# 1  0.0  1.0  NaN      2
# 2  NaN  1.0  0.0      2
# 3  NaN  0.0  NaN      3
# 4  NaN  0.0  NaN      3

# %%
# example_DRules.to_csv('./Datasets/example_DRules.csv', index=False)
